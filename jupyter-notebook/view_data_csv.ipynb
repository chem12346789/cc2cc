# %%
import pandas as pd

data = pd.read_csv("../data/save/dual_coef-final-7538.csv")

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.abs(data["predict_error"].to_numpy()))
plt.plot(-np.abs(data["predict_error_abs"].to_numpy()))

# %%
index_ = np.argsort(np.abs(data["predict_error_abs"].to_numpy()))[::-1][:50]
plt.plot(data["predict_error_abs"].to_numpy()[index_])
print(data["index"].to_numpy()[index_])
print(data["predict_error_abs"].to_numpy()[index_])
# Out:
# ['3_2_-3_3' '2_2_-2_-2' '2_-2_-2_2' '2_-2_2_-2' '4_-2_-3_3' '2_-2_2_-3'
#  '3_-4_1_2' '5_2_-3_-2' '12_-12_-12_-12' '4_5_-5_-5' '12_-12_0_-12'
#  '5_3_-7_-4' '3_-3_-2_3' '12_12_-12_-12' '2_2_-2_-3' '5_4_-6_-6'
#  '4_2_-3_2' '5_-4_2_-7' '5_-3_1_-2' '2_-2_-2_-2' '2_2_-2_2' '3_3_-3_2'
#  '2_2_-2_1' '2_2_-3_2' '5_2_-3_-7' '2_-3_2_-2' '3_-2_2_-4' '3_-4_-2_3'
#  '3_-3_2_-2' '5_-8_-3_3' '2_-3_2_-1' '2_-3_-2_3' '2_-3_-2_2' '3_3_-3_-2'
#  '12_-12_12_-12' '4_2_-3_-4' '12_-12_-12_12' '2_0_-2_2' '2_2_-3_-2'
#  '12_-12_0_12' '4_-2_2_-4' '2_-2_-1_2' '2_-2_-3_2' '3_-4_3_-2' '2_2_1_-3'
#  '3_-3_3_-3' '3_3_-2_-3' '3_1_-3_2' '3_-3_2_-3' '2_3_-3_-2']
# [1.23347373 0.72690151 0.71275964 0.4935532  0.1745526  0.16606161
#  0.16266609 0.15106522 0.1482269  0.13188299 0.12635641 0.12398627
#  0.12028636 0.11420725 0.11356016 0.11164625 0.10934532 0.10222554
#  0.10010539 0.09138494 0.09131137 0.09102657 0.09017878 0.0857575
#  0.08540762 0.08413965 0.080709   0.07836467 0.07804369 0.07703839
# ...
