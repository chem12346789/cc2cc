# %%
cube_use = 3
# %set_env DFT2CC_CUBE_USE={cube_use}
# Out:
# env: DFT2CC_CUBE_USE=3

# %%
from torchinfo import summary
from cc2cc.utils.model.transformer import Model

import torch

device = torch.device("cuda")
model = Model().to(device)

print(
    summary(
        model,
        input_size=(302*75*5, 4, cube_use, cube_use, cube_use),
        depth=10,
        dtypes=[torch.float32],
        mode="train",
    )
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from torchinfo import summary
#       2 from cc2cc.utils.model.transformer import Model
#       4 import torch
#
# ModuleNotFoundError: No module named 'torchinfo'

# %%
print(f"{302 * 75 * 30:>10}")
print(f"{1000000:>10}")
# Out:
#     679500
#    1000000
