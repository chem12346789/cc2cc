# %%
from torchinfo import summary
from dft2cc.utils.model.cnn3d import Model

device = torch.device("cpu")
model = Model(
)

print(
    summary(
        model,
        input_size=(1, 2*10, 4, 3, 3, 3),
        depth=10,
        dtypes=[torch.float32],
        mode="train",
    )
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from torchinfo import summary
# ----> 2 from dft2cc.utils.model.cnn3d import Model
#       4 import torch
#       5 import torch.nn as nn
#
# ModuleNotFoundError: No module named 'dft2cc'

# %%
124.15 496.49 1985.72
# Out:
#   Cell In[3], line 1
#     124.15 496.49 1985.72
#            ^
# SyntaxError: invalid syntax
