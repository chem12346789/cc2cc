# %%
from torchinfo import summary
from dft2cc.utils.model.cnn3d import Model

import torch

device = torch.device("cpu")
model = Model(
).double().to(device)

print(
    summary(
        model,
        input_size=(2**15, 4, 3, 3, 3),
        depth=10,
        dtypes=[torch.float64],
        mode="train",
    )
)
# Out:
# MAIN_PATH: /home/dhem/workspace/2024.3
# DATA_PATH: /home/dhem/workspace/2024.3/data/grids_dft
# DATA_SAVE_PATH: /home/dhem/workspace/2024.3/data/grids_dft/saved_data
# DATA_TEST_PATH: /home/dhem/workspace/2024.3/data/test
# CNN3D: False
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Model                                    [32768, 1]                --
# ├─Sequential: 1-1                        [32768, 64, 1, 1, 1]      --
# │    └─Conv3d: 2-1                       [32768, 64, 1, 1, 1]      6,976
# │    └─ReLU: 2-2                         [32768, 64, 1, 1, 1]      --
# ├─Sequential: 1-2                        [32768, 1]                --
# │    └─Linear: 2-3                       [32768, 16]               1,040
# │    └─ReLU: 2-4                         [32768, 16]               --
# │    └─Linear: 2-5                       [32768, 4]                68
# │    └─ReLU: 2-6                         [32768, 4]                --
# ...

# %%
124.15 496.49 1985.72
# Out:
#   Cell In[3], line 1
#     124.15 496.49 1985.72
#            ^
# SyntaxError: invalid syntax
