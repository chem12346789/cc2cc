# %%
cube_use = 3
# %set_env DFT2CC_CUBE_USE={cube_use}
# Out:
# env: DFT2CC_CUBE_USE=3

# %%
from torchinfo import summary
from cc2cc.utils.model.cnn3d import Model

import torch

device = torch.device("cuda")
model = Model().to(device)

print(
    summary(
        model,
        input_size=(302*75*5, 4, cube_use, cube_use, cube_use),
        depth=10,
        dtypes=[torch.float32],
        mode="train",
    )
)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model                                    [113250, 1]               28,812
# ├─Extractor: 1-1                         [113250, 27, 4]           --
# │    └─Linear: 2-1                       [113250, 27, 4]           20
# │    └─GELU: 2-2                         [113250, 27, 4]           --
# │    └─ModuleList: 2-3                   --                        --
# │    │    └─ABlock: 3-1                  [113250, 27, 4]           --
# │    │    │    └─Attention: 4-1          [113250, 27, 4]           --
# │    │    │    │    └─Linear: 5-1        [113250, 27, 12]          60
# │    │    │    │    └─Linear: 5-2        [113250, 27, 4]           20
# │    │    │    └─Linear: 4-2             [113250, 27, 16]          80
# │    │    │    └─Linear: 4-3             [113250, 27, 4]           68
# │    │    └─ABlock: 3-2                  [113250, 27, 4]           --
# │    │    │    └─Attention: 4-4          [113250, 27, 4]           --
# │    │    │    │    └─Linear: 5-3        [113250, 27, 12]          60
# │    │    │    │    └─Linear: 5-4        [113250, 27, 4]           20
# │    │    │    └─Linear: 4-5             [113250, 27, 16]          80
# │    │    │    └─Linear: 4-6             [113250, 27, 4]           68
# │    │    └─ABlock: 3-3                  [113250, 27, 4]           --
# │    │    │    └─Attention: 4-7          [113250, 27, 4]           --
# │    │    │    │    └─Linear: 5-5        [113250, 27, 12]          60
# │    │    │    │    └─Linear: 5-6        [113250, 27, 4]           20
# │    │    │    └─Linear: 4-8             [113250, 27, 16]          80
# │    │    │    └─Linear: 4-9             [113250, 27, 4]           68
# │    └─Linear: 2-4                       [113250, 27, 4]           20
# │    └─Linear: 2-5                       [113250, 27, 4]           16
# ├─Sequential: 1-2                        [113250, 1]               --
# │    └─Linear: 2-6                       [113250, 108]             11,772
# │    └─GELU: 2-7                         [113250, 108]             --
# │    └─Linear: 2-8                       [113250, 108]             11,772
# │    └─GELU: 2-9                         [113250, 108]             --
# │    └─Linear: 2-10                      [113250, 108]             11,772
# │    └─GELU: 2-11                        [113250, 108]             --
# │    └─Linear: 2-12                      [113250, 1]               109
# ==========================================================================================
# Total params: 64,977
# Trainable params: 64,977
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 4.10
# ==========================================================================================
# Input size (MB): 48.92
# Forward/backward pass size (MB): 3229.89
# Params size (MB): 0.14
# Estimated Total Size (MB): 3278.96
# ==========================================================================================

# %%
print(f"{302 * 75 * 30:>10}")
print(f"{1000000:>10}")
# Out:
#     679500
#    1000000
