# %%
import pandas as pd
import numpy as np

data_path_list = [
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-3034763_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-3769574_gmtkn-cc-pVDZ.csv",
]

for i in range(5):
    for data_path in data_path_list:
        data = pd.read_csv(data_path)

        if len(data) > (i * 100):
            data_min = np.min(data["delta_scf"].to_numpy()[i * 100 : i * 100 + 100])
            data_max = np.max(data["delta_scf"].to_numpy()[i * 100 : i * 100 + 100])
            print(data_max - data_min)
        else:
            print("NAN")
    print("")
# Out:
# 0.0024258731862940586
# 0.0003501788642950032
#
# 0.00804270516647676
# NAN
#
# 0.015257491429133907
# NAN
#
# 0.017089563116112316
# NAN
#
# NAN
# NAN
