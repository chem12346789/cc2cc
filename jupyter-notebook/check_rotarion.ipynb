# %%
import pandas as pd
import numpy as np

data_path_list = [
    # "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-125310_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-3815835_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-499265_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-1513512_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-3886482_gmtkn-cc-pVDZ.csv",
]

for i in range(5):
    for data_path in data_path_list:
        data = pd.read_csv(data_path)

        if len(data) > (i * 100):
            data_scf_min = np.min(data["delta_scf"].to_numpy()[i * 100 : i * 100 + 100])
            data_scf_max = np.max(data["delta_scf"].to_numpy()[i * 100 : i * 100 + 100])
            data_dft_min = np.min(data["delta_dft"].to_numpy()[i * 100 : i * 100 + 100])
            data_dft_max = np.max(data["delta_dft"].to_numpy()[i * 100 : i * 100 + 100])
            print(data_scf_max - data_scf_min, data_dft_max - data_dft_min)
        else:
            print("NAN")
    print("")
# Out:
# 0.3275608377715153 0.0010787075538019053
# 0.2196481886492891 0.0017277520690299752
# 0.08121583445758271 0.0014146486723092266
# 0.07067136634346251 0.0012721052649595777
#
# 0.6413226251148636 0.005806343776043832
# 0.4349568868585725 0.006122827624949423
# 0.14263314347538447 0.007559250230116277
# 0.3006624851319275 0.006665573375329359
#
# 0.8048253685711195 0.018812051181100742
# 0.5206260924991515 0.016337265866184225
# 0.16890390462497296 0.01910394881110733
# 0.37201937311988176 0.020521270318397455
#
# 1.1985436449289204 0.04940754974796846
# 0.6911047062021254 0.043374676154826375
# 0.262515880361745 0.05497557172230927
# 0.5064739335670634 0.049446372455520304
#
# 3.6357836982659815 0.3532404035768195
# 1.4337162255604623 0.3039723314935827
# 0.6764403611164713 0.27833643801955077
# 0.45564221162645957 0.2562306771837939
