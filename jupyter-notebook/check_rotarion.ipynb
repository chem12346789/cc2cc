# %%
import pandas as pd
import numpy as np

data_path_list = [
    # "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-2453600_gmtkn-cc-pVDZ.csv",
    # "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-1235076_gmtkn-cc-pVDZ.csv",
    # "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-4190857_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-4192002_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-1256130_gmtkn-cc-pVDZ.csv",
]

for i in range(5):
    for data_path in data_path_list:
        data = pd.read_csv(data_path)

        if len(data) > (i * 100):
            data_scf_min = np.min(data["delta_scf"].to_numpy()[i * 100 : i * 100 + 100])
            data_scf_max = np.max(data["delta_scf"].to_numpy()[i * 100 : i * 100 + 100])
            data_dft_min = np.min(data["delta_dft"].to_numpy()[i * 100 : i * 100 + 100])
            data_dft_max = np.max(data["delta_dft"].to_numpy()[i * 100 : i * 100 + 100])
            print(data_scf_max - data_scf_min, data_dft_max - data_dft_min)
        else:
            print("NAN")
    print("")
# Out:
# 0.0570826022034598 0.0012239054886293843
# 0.01697721116222195 0.0019235110306965453
#
# 0.2293589968703027 0.006532617234540794
# 0.03698936840378009 0.007113662157962608
#
# 0.3486671534108261 0.01904453844974796
# 0.0458349621841907 0.018361116894993756
#
# 0.576636352533205 0.05246231563586434
# 0.07409450879815971 0.05619149943629509
#
# 1.4959458002076573 0.19010648163680344
# 0.07974391306057171 0.2532199391165477
