# %%
import pandas as pd
import numpy as np

data_path_list = [
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-2124002_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-4062375_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-4063318_gmtkn-cc-pVDZ.csv",
]

for i in range(5):
    for data_path in data_path_list:
        data = pd.read_csv(data_path)

        if len(data) > (i * 100):
            data_min = np.min(data["delta_scf"].to_numpy()[i * 100 : i * 100 + 100])
            data_max = np.max(data["delta_scf"].to_numpy()[i * 100 : i * 100 + 100])
            print(data_max - data_min)
        else:
            print("NAN")
    print("")
# Out:
# 0.05751794445571229
# 1.6952469787061846
# 0.06373314236113448
#
# 0.14124242059594339
# 2.9626344917954737
# NAN
#
# 0.1285648974511604
# NAN
# NAN
#
# 0.18736402617961367
# NAN
# NAN
#
# 0.09020238285521032
# NAN
# NAN
