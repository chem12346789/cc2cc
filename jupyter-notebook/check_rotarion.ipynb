# %%
import pandas as pd
import numpy as np

data_path_list = [
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-1880714_gmtkn-cc-pVDZ_bk.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-1880714_gmtkn-cc-pVDZ.csv",
    "/home/chenzihao/workspace/cc2cc_test5/validate/ccdft_cc-pVDZ_atom-1-2762936_gmtkn-cc-pVDZ.csv",
]

for i in range(3):
    for data_path in data_path_list:
        data = pd.read_csv(data_path)

        if len(data) > i*100:
            data_min = np.min(data["delta_scf"].to_numpy()[i*100:i*100 + 100])
            data_max = np.max(data["delta_scf"].to_numpy()[i*100:i*100 + 100])
            print(data_max - data_min)
        else:
            print("NAN")
    print("")
# Out:
# 0.13212374907625346
# 0.3007847848757734
# 0.009339658511144933
#
# 0.17882056877310504
# NAN
# 0.01526043064608018
#
# 0.1658504747133449
# NAN
# NAN
