# %%
import numpy as np

# data_nega = np.load(
#     "/home/dhem/workspace/2025.1/data/test/W4_11-h2_cc-pVDZ_0_3_-0.0010_default_cc.npz"
# )
# data_equ = np.load(
#     "/home/dhem/workspace/2025.1/data/test/W4_11-h2_cc-pVDZ_0_3_0.0000_default_cc.npz"
# )
# data_posi = np.load(
#     "/home/dhem/workspace/2025.1/data/test/W4_11-h2_cc-pVDZ_0_3_0.0010_default_cc.npz"
# )


# print(
#     (data_posi["e_cc"] - data_nega["e_cc"]) / 2 / 0.001 * 0.52917721092
# )
# print(
#     (data_posi["e_dft"] - data_nega["e_dft"]) / 2 / 0.001 * 0.52917721092
# )
# print((-1.1634271112282384 - -1.163424463023373) / 0.0001 * 0.52917721092)

print((-919.2671911858089 - -919.2672053332417) / (-0.0003772981826877242 *2))
print((-919.2807279745771 - -919.2807409149847) / (-0.0003772981826877242 *2))
print((-920.3958138713745 - -920.3958289836611) / (-0.0003772981826877242 *2))
# Out:
# -0.01874834475307524
# -0.017148780718209206
# -0.020026980417852634

# %%
1.8863022643484626 - 1.8866795625311503
# Out:
# -0.0003772981826877242

# %%
-919.2672053332417
-919.2807409149847
-920.3958289836611
# Out:
# (-919.2671258775104, -919.2845715237656, -920.3957442317596)
