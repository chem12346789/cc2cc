# %%
import torch
from pathlib import Path

checkpoint_dir = Path(
    "/home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/"
)
# model = "transformer_c"
model = "transformer_large"

for checkpoint_path in checkpoint_dir.glob("*.pth"):
    print(checkpoint_path)
    device = "cpu"
    state_dict = torch.load(checkpoint_path, map_location=device, weights_only=True)
    torch.save({"state_dict": state_dict, "model": model}, checkpoint_path)
# Out:
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/3250.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/5750.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/7250.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/6000.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/4750.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/5250.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/1000.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/1500.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/2000.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/6250.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/7000.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/5000.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/500.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/6750.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/4250.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/750.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/4000.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/6500.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/2250.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/7750.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/7500.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/3000.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/2750.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/250.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/5500.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/1250.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/4500.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/2500.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/1750.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/3750.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/3500.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-1424849/0.pth
