# %%
import torch
from pathlib import Path

checkpoint_dir = Path(
    "/home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/"
)
# model = "transformer_c"
model = "transformer_dense_no_normal"

for checkpoint_path in checkpoint_dir.glob("*.pth"):
    print(checkpoint_path)
    device = "cpu"
    state_dict = torch.load(checkpoint_path, map_location=device, weights_only=True)

    # torch.save({"state_dict": state_dict, "model": model}, checkpoint_path)

    state_dict["model"] = model
    torch.save(state_dict, checkpoint_path)
# Out:
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/755.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/240.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/3250.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/130.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/210.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/685.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/3255.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/5.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/740.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/4750.pth
# /home/chenzihao/workspace/cc2cc_test5/checkpoints/checkpoint_atom-1-499265/190.pth
# ...
