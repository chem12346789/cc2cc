# %%
data = ["G21EA-EA_23n_cc-pVDZ_0-1_1_0.0000_default", "G21IP-IP_80_cc-pVDZ_0-1_1_0.0000_default", "GAPS-GaAs_cc-pVDZ_0-1_1_0.0000_default", "GAPS-GaP_cc-pVDZ_0-1_1_0.0000_default", "MRADC-cs-stretch_cc-pVDZ_0-1_1_0.0000_default", "GAPS-CaF2_cc-pVDZ_0-1_1_0.0000_default", "GAPS-MgCl2_cc-pVDZ_0-1_1_0.0000_default", "W4_11-c-hooo_cc-pVDZ_0-1_1_0.0000_default", "BH76-RKT15_cc-pVDZ_0-1_1_0.0000_default"]
for item in data:
    print(item.split("_cc-pVDZ")[0])
# Out:
# G21EA-EA_23n
# G21IP-IP_80
# GAPS-GaAs
# GAPS-GaP
# MRADC-cs-stretch
# GAPS-CaF2
# GAPS-MgCl2
# W4_11-c-hooo
# BH76-RKT15
