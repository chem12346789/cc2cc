# %%
data = [
    "ALKBDE10-li_cc-pVDZ_0-1_1_0.0000_default",
    "ALKBDE10-na_cc-pVDZ_0-1_1_0.0000_default",
    "G21IP-be+_cc-pVDZ_0-1_1_0.0000_default",
    "G21IP-mg+_cc-pVDZ_0-1_1_0.0000_default",
    "GW100-7440-59-7_cc-pVDZ_0-1_1_0.0000_default",
    "SIE4x4-he+_cc-pVDZ_0-1_1_0.0000_default",
    "W4_11-h_cc-pVDZ_0-1_1_0.0000_default",
    "W4_11-n_cc-pVDZ_0-1_1_0.0000_default",
    "SIE4x4-h2+_1.0_cc-pVDZ_0-1_1_0.0000_default",
    "SIE4x4-h2+_1.25_cc-pVDZ_0-1_1_0.0000_default",
    "SIE4x4-h2+_1.5_cc-pVDZ_0-1_1_0.0000_default",
    "SIE4x4-h2+_1.75_cc-pVDZ_0-1_1_0.0000_default",
]
for item in data:
    print(item.split("_cc-pVDZ")[0], end=" ")
# Out:
# ALKBDE10-li ALKBDE10-na G21IP-be+ G21IP-mg+ GW100-7440-59-7 SIE4x4-he+ W4_11-h W4_11-n SIE4x4-h2+_1.0 SIE4x4-h2+_1.25 SIE4x4-h2+_1.5 SIE4x4-h2+_1.75
