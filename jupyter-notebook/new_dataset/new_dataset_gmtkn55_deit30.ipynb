# %%
import sys
import json
from pathlib import Path

import numpy as np

BASIS = "def2-svp"

# %%
with open(f"gmtkn-{BASIS}.json", "r") as f:
    dict_gmtkn = json.load(f)

dataset_dict = {
    "Amino20x4": [23.31, [28, 54]],
    "WCPT18": [1.62, [15]],
    "FH51": [1.83, [24, 30]],
    "BHROT27": [9.06, [16, 26]],
    "DC13": [1.03, [1]],
    "BH76": [3.05, [5]],
    "HEAVY28": [45.79, [16]],
    "PX13": [1.70, [9]],
    "BHPERI": [2.72, [11]],
    "G21EA": [1.69, [14, 25]],
    "DIPCS10": [0.09, [7]],
    "W4_11": [0.19, [30, 57, 132]],
    "S66": [10.40, [6, 50]],
    "MB16_43": [0.12, [10]],
    "HAL59": [12.38, [40, 57]],
    "BUT14DIOL": [20.30, [13]],
    "PNICO23": [13.30, [16]],
    "ACONF": [30.99, [10]],
    "CDIE20": [14.02, [9]],
    "BSR36": [3.51, [31]],
    "MCONF": [11.43, [1]],
    "SIE4x4": [1.69, [15]],
}
dict_ = {"molecule": [], "spin": {}, "charge": {}}
for dataset, list_dataset in dataset_dict.items():
    print(dataset)
    for index in list_dataset[1]:
        print(dict_gmtkn[f"reaction-{dataset}"][str(index-1)])

# with open(f"gmtkn-diet30-{BASIS}.json", "w") as f:
#     json.dump(dict_new, f)
# Out:
# Amino20x4
# {'systems': ['GLU_xbi', 'GLU_xad'], 'stoichiometry': ['-1', '1'], 'reference': 5.216}
# {'systems': ['PHE_xaw', 'PHE_xar'], 'stoichiometry': ['-1', '1'], 'reference': 1.719}
# WCPT18
# {'systems': ['reac6', 'h2o', 'ts6h2o'], 'stoichiometry': ['-1', '-1', '1'], 'reference': 59.63}
# FH51
# {'systems': ['dimethyloxirane', 'H2O', 'butanediol'], 'stoichiometry': ['-1', '-1', '1'], 'reference': -22.45}
# {'systems': ['C3H7NCO', 'H2O', 'C3H7NH2', 'CO2'], 'stoichiometry': ['-1', '-1', '1', '1'], 'reference': -16.98}
# BHROT27
# {'systems': ['acetamide_RC', 'acetamide_TS2'], 'stoichiometry': ['-1', '1'], 'reference': 14.52}
# {'systems': ['ethylthiourea_180', 'ethylthiourea_TS2'], 'stoichiometry': ['-1', '1'], 'reference': 17.2}
# DC13
# {'systems': ['ISO_E36', 'ISO_P36'], 'stoichiometry': ['1', '-1'], 'reference': -1.0}
# BH76
# {'systems': ['h', 'hcl', 'hclhts'], 'stoichiometry': ['-1', '-1', '1'], 'reference': 17.8}
# HEAVY28
# {'systems': ['sbh3_h2o', 'sbh3', 'h2o'], 'stoichiometry': ['-1', '1', '1'], 'reference': 1.57}
# PX13
# {'systems': ['hf_2', 'hf_2_ts'], 'stoichiometry': ['-1', '1'], 'reference': 42.3}
# BHPERI
# {'systems': ['13r_1', '13_c2h4', '13ts_1a'], 'stoichiometry': ['-1', '-1', '1'], 'reference': 27.6}
# G21EA
# {'systems': ['EA_14n', 'EA_14'], 'stoichiometry': ['1', '-1'], 'reference': 29.3}
# {'systems': ['EA_25n', 'EA_25'], 'stoichiometry': ['1', '-1'], 'reference': 54.7}
# DIPCS10
# {'systems': ['h2s', 'h2s_2+'], 'stoichiometry': ['-1', '1'], 'reference': 733.0}
# W4_11
# {'systems': ['hcl', 'h', 'cl'], 'stoichiometry': ['-1', '1', '1'], 'reference': 107.499}
# {'systems': ['bf', 'b', 'f'], 'stoichiometry': ['-1', '1', '1'], 'reference': 182.517}
# {'systems': ['oclo', 'o', 'cl'], 'stoichiometry': ['-1', '2', '1'], 'reference': 128.12}
# S66
# {'systems': ['06A', '06B', '06'], 'stoichiometry': ['1', '1', '-1'], 'reference': 7.55}
# {'systems': ['50A', '50B', '50'], 'stoichiometry': ['1', '1', '-1'], 'reference': 2.87}
# MB16_43
# {'systems': ['10', 'H2', 'BH3', 'CH4', 'N2', 'F2', 'MgH2', 'SiH4', 'Cl2'], 'stoichiometry': ['-2', '-14', '2', '6', '1', '1', '2', '2', '1'], 'reference': 46.3073}
# HAL59
# {'systems': ['MeI_OPH3', 'MeI', 'OPH3'], 'stoichiometry': ['-1', '1', '1'], 'reference': 3.34}
# {'systems': ['28_CH3I-benA', '28_CH3I-benB', '28_CH3I-benAB'], 'stoichiometry': ['1', '1', '-1'], 'reference': 2.48}
# BUT14DIOL
# {'systems': ['B1', 'B14'], 'stoichiometry': ['-1', '1'], 'reference': 2.22}
# PNICO23
# {'systems': ['16', '16a', '16b'], 'stoichiometry': ['-1', '1', '1'], 'reference': 1.78}
# ACONF
# {'systems': ['H_ttt', 'H_ggg'], 'stoichiometry': ['-1', '1'], 'reference': 1.25}
# CDIE20
# {'systems': ['R43', 'P43'], 'stoichiometry': ['-1', '1'], 'reference': 2.9}
# BSR36
# {'systems': ['c2h6', 'r16', 'ch4'], 'stoichiometry': ['12', '-1', '-12'], 'reference': 24.96}
# MCONF
# {'systems': ['1', '2'], 'stoichiometry': ['-1', '1'], 'reference': 0.39}
# SIE4x4
# {'systems': ['h2o', 'h2o+', 'h2o2+_1.5'], 'stoichiometry': ['1', '1', '-1'], 'reference': 16.9}
