# %%
import json
from pathlib import Path

import numpy as np

from pyscf import gto

import sys

BASIS = "def2-svp"

# %%
dict_ = {"molecule": [], "spin": {}, "charge": {}}

data_path = Path("./sets/gmntk55")
# download the data from https://github.com/obackhouse/gmtkn
# Note
#   1) The data is also included a additional dataset ADDON (Se, Ge, As, Te, I, Bi, Pb, Sb).
#   3) The data is also included a additional dataset BH76RC (76 reaction curves).
#   2) The data included GMTKN55, GW100, GAPS, MRADC, ACC24, S30L, BH9. So the latter should be removed if you want to use the former.
# --- IGNORE ---
max_num_atom = -1

for python_path in data_path.glob("*.py"):
    if python_path.name == "__init__.py":
        continue
    exec(python_path.read_text())
    # load the systems and reactions from the executed python file
    dataset = python_path.stem
    print(f"Processing {dataset}")
    dict_[f"molecule_{dataset}"] = []

    for i_name in systems:
        molecule = []
        for i_atom in range(len(systems[i_name]["atoms"])):
            molecule.append(
                [
                    systems[i_name]["atoms"][i_atom],
                    float(systems[i_name]["coords"][i_atom][0]),
                    float(systems[i_name]["coords"][i_atom][1]),
                    float(systems[i_name]["coords"][i_atom][2]),
                ]
            )

        try:
            mol = gto.M(
                atom=molecule,
                basis=BASIS,
                # ecp=BASIS,
                verbose=0,
                charge=systems[i_name]["charge"],
                spin=systems[i_name]["spin"],
                unit="B",
            )
            mol.build()
            max_num_atom = max(max_num_atom, len(molecule))
        except Exception as e:
            print(molecule)
            print(f"Error in {i_name}: {e}")
            continue

        molecule = []
        for i_atom in mol._atom:
            molecule.append(
                [
                    i_atom[0],
                    i_atom[1][0],
                    i_atom[1][1],
                    i_atom[1][2],
                ]
            )

        if dataset != "BH76RC":
            dict_i_name = f"{dataset}-{i_name}"
            dict_[dict_i_name] = molecule
            dict_[f"molecule_{dataset}"].append(dict_i_name)
            dict_["molecule"].append(dict_i_name)
            dict_["charge"][dict_i_name] = systems[i_name]["charge"]
            dict_["spin"][dict_i_name] = systems[i_name]["spin"]

    dict_[f"reaction-{dataset}"] = {}
    for i_reaction, reaction in enumerate(reactions):
        dict_[f"reaction-{dataset}"][i_reaction] = {
            "systems": reaction["systems"],
            "stoichiometry": reaction["stoichiometry"],
            "reference": reaction["reference"],
        }

    for number_atom in range(max_num_atom + 1):
        dict_[f"molecule{number_atom}-{dataset}"] = []

    for molecule in dict_[f"molecule_{dataset}"]:
        num_heavy_atom = 0
        num_atom = 0
        for atom in dict_[molecule]:
            num_atom += 1
            if atom[0].upper() != "H":
                num_heavy_atom += 1

        if num_heavy_atom == 0:
            if num_atom == 1:
                dict_[f"molecule0-{dataset}"].append(molecule)
            else:
                dict_[f"molecule1-{dataset}"].append(molecule)
        elif num_heavy_atom == 1:
            if num_atom == 1:
                dict_[f"molecule0-{dataset}"].append(molecule)
            else:
                dict_[f"molecule1-{dataset}"].append(molecule)
        else:
            dict_[f"molecule{num_heavy_atom}-{dataset}"].append(molecule)

for number_atom in range(max_num_atom):
    dict_[f"molecule{number_atom}"] = []

for molecule in dict_["molecule"]:
    num_heavy_atom = 0
    num_atom = 0
    for atom in dict_[molecule]:
        num_atom += 1
        if atom[0].upper() != "H":
            num_heavy_atom += 1

    if num_heavy_atom == 0:
        if num_atom == 1:
            dict_[f"molecule0"].append(molecule)
        else:
            dict_[f"molecule1"].append(molecule)
    elif num_heavy_atom == 1:
        if num_atom == 1:
            dict_[f"molecule0"].append(molecule)
        else:
            dict_[f"molecule1"].append(molecule)
    else:
        dict_[f"molecule{num_heavy_atom}"].append(molecule)
print()
print("DONE")
# Out:
# Processing G2RC
# Processing DC13
# Processing S66
# Processing WCPT18
# Processing RC21
# Processing PNICO23
# Processing INV24
# Processing TAUT15
# Processing IL16
# Processing PA26
# Processing SIE4x4
# Processing DARC
# Processing ADDON
# Processing HAL59
# Processing ISO34
# Processing BHPERI
# Processing ALK8
# Processing G21EA
# Processing UPU23
# Processing PCONF21
# Processing BH76RC
# Processing FH51
# Processing YBDE18
# Processing PArel
# Processing IDISP
# Processing Amino20x4
# Processing ADIM6
# Processing ALKBDE10
# Processing ISOL24
# Processing RSE43
# Processing G21IP
# Processing BHROT27
# Processing W4_11
# Processing C60ISO
# Processing HEAVYSB11
# Processing DIPCS10
# Processing CDIE20
# Processing PX13
# Processing AL2X6
# Processing BHDIV10
# Processing CHB6
# Processing AHB21
# Processing S22
# Processing WATER27
# Processing BSR36
# Processing ACONF
# Processing BH76
# Processing ICONF
# Processing MB16_43
# Processing RG18
# Processing NBPRC
# Processing BUT14DIOL
# Processing HEAVY28
# Processing SCONF
# Processing CARBHB12
# Processing MCONF
#
# DONE

# %%
dict_new = {}
for key in dict_:
    if key.startswith("molecule"):
        if dict_[key]:
            dict_new[key] = dict_[key]
    else:
        dict_new[key] = dict_[key]

with open(f"gmtkn-{BASIS}.json", "w") as f:
    json.dump(dict_new, f)

# %%
# compare it with /home/dhem/workspace/2025.1/cc2cc/utils/gmtkn-def2.json
with open(f"/home/dhem/workspace/2025.1/cc2cc/utils/gmtkn-def2.json", "r") as f:
    dict_check = json.load(f)

# print(f"Number of molecules: {len(dict_new['molecule'])}")
# print(f"Number of molecules: {len(dict_check['molecule'])}")

# check keys

for key in dict_new:
    if key not in dict_check:
        print(f"Key {key} is not in dict_check")
    else:
        if isinstance(dict_new[key], list):
            if len(dict_new[key]) != len(dict_check[key]):
                print(f"Key {key} has different number of molecules: {len(dict_new[key])} vs {len(dict_check[key])}")
        elif isinstance(dict_new[key], dict):
            for key2 in dict_new[key]:
                if key2 not in dict_check[key]:
                    print(f"Key {key2} is not in dict_check[{key}]")
            
for key in dict_check:
    if key not in dict_new:
        print(f"Key {key} is not in dict_new")
# Out:
# Key ADDON-Ge is not in dict_check[spin]
# Key ADDON-As is not in dict_check[spin]
# Key ADDON-Se is not in dict_check[spin]
# Key ADDON-Sb is not in dict_check[spin]
# Key ADDON-Te is not in dict_check[spin]
# Key ADDON-I is not in dict_check[spin]
# Key ADDON-Bi is not in dict_check[spin]
# Key ADDON-Pb is not in dict_check[spin]
# Key ADDON-Ge is not in dict_check[charge]
# Key ADDON-As is not in dict_check[charge]
# Key ADDON-Se is not in dict_check[charge]
# Key ADDON-Sb is not in dict_check[charge]
# Key ADDON-Te is not in dict_check[charge]
# Key ADDON-I is not in dict_check[charge]
# Key ADDON-Bi is not in dict_check[charge]
# Key ADDON-Pb is not in dict_check[charge]
# Key 0 is not in dict_check[reaction-G2RC]
# Key 1 is not in dict_check[reaction-G2RC]
# Key 2 is not in dict_check[reaction-G2RC]
# Key 3 is not in dict_check[reaction-G2RC]
# Key 4 is not in dict_check[reaction-G2RC]
# Key 5 is not in dict_check[reaction-G2RC]
# Key 6 is not in dict_check[reaction-G2RC]
# Key 7 is not in dict_check[reaction-G2RC]
# Key 8 is not in dict_check[reaction-G2RC]
# Key 9 is not in dict_check[reaction-G2RC]
# Key 10 is not in dict_check[reaction-G2RC]
# Key 11 is not in dict_check[reaction-G2RC]
# Key 12 is not in dict_check[reaction-G2RC]
# Key 13 is not in dict_check[reaction-G2RC]
# Key 14 is not in dict_check[reaction-G2RC]
# Key 15 is not in dict_check[reaction-G2RC]
# Key 16 is not in dict_check[reaction-G2RC]
# Key 17 is not in dict_check[reaction-G2RC]
# Key 18 is not in dict_check[reaction-G2RC]
# Key 19 is not in dict_check[reaction-G2RC]
# Key 20 is not in dict_check[reaction-G2RC]
# Key 21 is not in dict_check[reaction-G2RC]
# Key 22 is not in dict_check[reaction-G2RC]
# Key 23 is not in dict_check[reaction-G2RC]
# Key 24 is not in dict_check[reaction-G2RC]
# Key 0 is not in dict_check[reaction-DC13]
# Key 1 is not in dict_check[reaction-DC13]
# Key 2 is not in dict_check[reaction-DC13]
# Key 3 is not in dict_check[reaction-DC13]
# Key 4 is not in dict_check[reaction-DC13]
# Key 5 is not in dict_check[reaction-DC13]
# Key 6 is not in dict_check[reaction-DC13]
# Key 7 is not in dict_check[reaction-DC13]
# Key 8 is not in dict_check[reaction-DC13]
# Key 9 is not in dict_check[reaction-DC13]
# Key 10 is not in dict_check[reaction-DC13]
# Key 11 is not in dict_check[reaction-DC13]
# Key 12 is not in dict_check[reaction-DC13]
# Key 0 is not in dict_check[reaction-S66]
# Key 1 is not in dict_check[reaction-S66]
# Key 2 is not in dict_check[reaction-S66]
# Key 3 is not in dict_check[reaction-S66]
# Key 4 is not in dict_check[reaction-S66]
# Key 5 is not in dict_check[reaction-S66]
# Key 6 is not in dict_check[reaction-S66]
# Key 7 is not in dict_check[reaction-S66]
# Key 8 is not in dict_check[reaction-S66]
# Key 9 is not in dict_check[reaction-S66]
# Key 10 is not in dict_check[reaction-S66]
# Key 11 is not in dict_check[reaction-S66]
# Key 12 is not in dict_check[reaction-S66]
# Key 13 is not in dict_check[reaction-S66]
# Key 14 is not in dict_check[reaction-S66]
# Key 15 is not in dict_check[reaction-S66]
# Key 16 is not in dict_check[reaction-S66]
# Key 17 is not in dict_check[reaction-S66]
# Key 18 is not in dict_check[reaction-S66]
# Key 19 is not in dict_check[reaction-S66]
# Key 20 is not in dict_check[reaction-S66]
# Key 21 is not in dict_check[reaction-S66]
# Key 22 is not in dict_check[reaction-S66]
# Key 23 is not in dict_check[reaction-S66]
# Key 24 is not in dict_check[reaction-S66]
# Key 25 is not in dict_check[reaction-S66]
# Key 26 is not in dict_check[reaction-S66]
# Key 27 is not in dict_check[reaction-S66]
# Key 28 is not in dict_check[reaction-S66]
# Key 29 is not in dict_check[reaction-S66]
# Key 30 is not in dict_check[reaction-S66]
# Key 31 is not in dict_check[reaction-S66]
# Key 32 is not in dict_check[reaction-S66]
# Key 33 is not in dict_check[reaction-S66]
# Key 34 is not in dict_check[reaction-S66]
# Key 35 is not in dict_check[reaction-S66]
# Key 36 is not in dict_check[reaction-S66]
# Key 37 is not in dict_check[reaction-S66]
# Key 38 is not in dict_check[reaction-S66]
# Key 39 is not in dict_check[reaction-S66]
# Key 40 is not in dict_check[reaction-S66]
# Key 41 is not in dict_check[reaction-S66]
# Key 42 is not in dict_check[reaction-S66]
# Key 43 is not in dict_check[reaction-S66]
# Key 44 is not in dict_check[reaction-S66]
# Key 45 is not in dict_check[reaction-S66]
# Key 46 is not in dict_check[reaction-S66]
# Key 47 is not in dict_check[reaction-S66]
# Key 48 is not in dict_check[reaction-S66]
# Key 49 is not in dict_check[reaction-S66]
# Key 50 is not in dict_check[reaction-S66]
# Key 51 is not in dict_check[reaction-S66]
# Key 52 is not in dict_check[reaction-S66]
# Key 53 is not in dict_check[reaction-S66]
# Key 54 is not in dict_check[reaction-S66]
# Key 55 is not in dict_check[reaction-S66]
# Key 56 is not in dict_check[reaction-S66]
# Key 57 is not in dict_check[reaction-S66]
# Key 58 is not in dict_check[reaction-S66]
# Key 59 is not in dict_check[reaction-S66]
# Key 60 is not in dict_check[reaction-S66]
# Key 61 is not in dict_check[reaction-S66]
# Key 62 is not in dict_check[reaction-S66]
# Key 63 is not in dict_check[reaction-S66]
# Key 64 is not in dict_check[reaction-S66]
# Key 65 is not in dict_check[reaction-S66]
# Key 0 is not in dict_check[reaction-WCPT18]
# Key 1 is not in dict_check[reaction-WCPT18]
# Key 2 is not in dict_check[reaction-WCPT18]
# Key 3 is not in dict_check[reaction-WCPT18]
# Key 4 is not in dict_check[reaction-WCPT18]
# Key 5 is not in dict_check[reaction-WCPT18]
# Key 6 is not in dict_check[reaction-WCPT18]
# Key 7 is not in dict_check[reaction-WCPT18]
# Key 8 is not in dict_check[reaction-WCPT18]
# Key 9 is not in dict_check[reaction-WCPT18]
# Key 10 is not in dict_check[reaction-WCPT18]
# Key 11 is not in dict_check[reaction-WCPT18]
# Key 12 is not in dict_check[reaction-WCPT18]
# Key 13 is not in dict_check[reaction-WCPT18]
# Key 14 is not in dict_check[reaction-WCPT18]
# Key 15 is not in dict_check[reaction-WCPT18]
# Key 16 is not in dict_check[reaction-WCPT18]
# Key 17 is not in dict_check[reaction-WCPT18]
# Key 0 is not in dict_check[reaction-RC21]
# Key 1 is not in dict_check[reaction-RC21]
# Key 2 is not in dict_check[reaction-RC21]
# Key 3 is not in dict_check[reaction-RC21]
# Key 4 is not in dict_check[reaction-RC21]
# Key 5 is not in dict_check[reaction-RC21]
# Key 6 is not in dict_check[reaction-RC21]
# Key 7 is not in dict_check[reaction-RC21]
# Key 8 is not in dict_check[reaction-RC21]
# Key 9 is not in dict_check[reaction-RC21]
# Key 10 is not in dict_check[reaction-RC21]
# Key 11 is not in dict_check[reaction-RC21]
# Key 12 is not in dict_check[reaction-RC21]
# Key 13 is not in dict_check[reaction-RC21]
# Key 14 is not in dict_check[reaction-RC21]
# Key 15 is not in dict_check[reaction-RC21]
# Key 16 is not in dict_check[reaction-RC21]
# Key 17 is not in dict_check[reaction-RC21]
# Key 18 is not in dict_check[reaction-RC21]
# Key 19 is not in dict_check[reaction-RC21]
# Key 20 is not in dict_check[reaction-RC21]
# Key 0 is not in dict_check[reaction-PNICO23]
# Key 1 is not in dict_check[reaction-PNICO23]
# Key 2 is not in dict_check[reaction-PNICO23]
# Key 3 is not in dict_check[reaction-PNICO23]
# Key 4 is not in dict_check[reaction-PNICO23]
# Key 5 is not in dict_check[reaction-PNICO23]
# Key 6 is not in dict_check[reaction-PNICO23]
# Key 7 is not in dict_check[reaction-PNICO23]
# Key 8 is not in dict_check[reaction-PNICO23]
# Key 9 is not in dict_check[reaction-PNICO23]
# Key 10 is not in dict_check[reaction-PNICO23]
# Key 11 is not in dict_check[reaction-PNICO23]
# Key 12 is not in dict_check[reaction-PNICO23]
# Key 13 is not in dict_check[reaction-PNICO23]
# Key 14 is not in dict_check[reaction-PNICO23]
# Key 15 is not in dict_check[reaction-PNICO23]
# Key 16 is not in dict_check[reaction-PNICO23]
# Key 17 is not in dict_check[reaction-PNICO23]
# Key 18 is not in dict_check[reaction-PNICO23]
# Key 19 is not in dict_check[reaction-PNICO23]
# Key 20 is not in dict_check[reaction-PNICO23]
# Key 21 is not in dict_check[reaction-PNICO23]
# Key 22 is not in dict_check[reaction-PNICO23]
# Key 0 is not in dict_check[reaction-INV24]
# Key 1 is not in dict_check[reaction-INV24]
# Key 2 is not in dict_check[reaction-INV24]
# Key 3 is not in dict_check[reaction-INV24]
# Key 4 is not in dict_check[reaction-INV24]
# Key 5 is not in dict_check[reaction-INV24]
# Key 6 is not in dict_check[reaction-INV24]
# Key 7 is not in dict_check[reaction-INV24]
# Key 8 is not in dict_check[reaction-INV24]
# Key 9 is not in dict_check[reaction-INV24]
# Key 10 is not in dict_check[reaction-INV24]
# Key 11 is not in dict_check[reaction-INV24]
# Key 12 is not in dict_check[reaction-INV24]
# Key 13 is not in dict_check[reaction-INV24]
# Key 14 is not in dict_check[reaction-INV24]
# Key 15 is not in dict_check[reaction-INV24]
# Key 16 is not in dict_check[reaction-INV24]
# Key 17 is not in dict_check[reaction-INV24]
# Key 18 is not in dict_check[reaction-INV24]
# Key 19 is not in dict_check[reaction-INV24]
# Key 20 is not in dict_check[reaction-INV24]
# Key 21 is not in dict_check[reaction-INV24]
# Key 22 is not in dict_check[reaction-INV24]
# Key 23 is not in dict_check[reaction-INV24]
# Key 0 is not in dict_check[reaction-TAUT15]
# Key 1 is not in dict_check[reaction-TAUT15]
# Key 2 is not in dict_check[reaction-TAUT15]
# Key 3 is not in dict_check[reaction-TAUT15]
# Key 4 is not in dict_check[reaction-TAUT15]
# Key 5 is not in dict_check[reaction-TAUT15]
# Key 6 is not in dict_check[reaction-TAUT15]
# Key 7 is not in dict_check[reaction-TAUT15]
# Key 8 is not in dict_check[reaction-TAUT15]
# Key 9 is not in dict_check[reaction-TAUT15]
# Key 10 is not in dict_check[reaction-TAUT15]
# Key 11 is not in dict_check[reaction-TAUT15]
# Key 12 is not in dict_check[reaction-TAUT15]
# Key 13 is not in dict_check[reaction-TAUT15]
# Key 14 is not in dict_check[reaction-TAUT15]
# Key 0 is not in dict_check[reaction-IL16]
# Key 1 is not in dict_check[reaction-IL16]
# Key 2 is not in dict_check[reaction-IL16]
# Key 3 is not in dict_check[reaction-IL16]
# Key 4 is not in dict_check[reaction-IL16]
# Key 5 is not in dict_check[reaction-IL16]
# Key 6 is not in dict_check[reaction-IL16]
# Key 7 is not in dict_check[reaction-IL16]
# Key 8 is not in dict_check[reaction-IL16]
# Key 9 is not in dict_check[reaction-IL16]
# Key 10 is not in dict_check[reaction-IL16]
# Key 11 is not in dict_check[reaction-IL16]
# Key 12 is not in dict_check[reaction-IL16]
# Key 13 is not in dict_check[reaction-IL16]
# Key 14 is not in dict_check[reaction-IL16]
# Key 15 is not in dict_check[reaction-IL16]
# Key 0 is not in dict_check[reaction-PA26]
# Key 1 is not in dict_check[reaction-PA26]
# Key 2 is not in dict_check[reaction-PA26]
# Key 3 is not in dict_check[reaction-PA26]
# Key 4 is not in dict_check[reaction-PA26]
# Key 5 is not in dict_check[reaction-PA26]
# Key 6 is not in dict_check[reaction-PA26]
# Key 7 is not in dict_check[reaction-PA26]
# Key 8 is not in dict_check[reaction-PA26]
# Key 9 is not in dict_check[reaction-PA26]
# Key 10 is not in dict_check[reaction-PA26]
# Key 11 is not in dict_check[reaction-PA26]
# Key 12 is not in dict_check[reaction-PA26]
# Key 13 is not in dict_check[reaction-PA26]
# Key 14 is not in dict_check[reaction-PA26]
# Key 15 is not in dict_check[reaction-PA26]
# Key 16 is not in dict_check[reaction-PA26]
# Key 17 is not in dict_check[reaction-PA26]
# Key 18 is not in dict_check[reaction-PA26]
# Key 19 is not in dict_check[reaction-PA26]
# Key 20 is not in dict_check[reaction-PA26]
# Key 21 is not in dict_check[reaction-PA26]
# Key 22 is not in dict_check[reaction-PA26]
# Key 23 is not in dict_check[reaction-PA26]
# Key 24 is not in dict_check[reaction-PA26]
# Key 25 is not in dict_check[reaction-PA26]
# Key 0 is not in dict_check[reaction-SIE4x4]
# Key 1 is not in dict_check[reaction-SIE4x4]
# Key 2 is not in dict_check[reaction-SIE4x4]
# Key 3 is not in dict_check[reaction-SIE4x4]
# Key 4 is not in dict_check[reaction-SIE4x4]
# Key 5 is not in dict_check[reaction-SIE4x4]
# Key 6 is not in dict_check[reaction-SIE4x4]
# Key 7 is not in dict_check[reaction-SIE4x4]
# Key 8 is not in dict_check[reaction-SIE4x4]
# Key 9 is not in dict_check[reaction-SIE4x4]
# Key 10 is not in dict_check[reaction-SIE4x4]
# Key 11 is not in dict_check[reaction-SIE4x4]
# Key 12 is not in dict_check[reaction-SIE4x4]
# Key 13 is not in dict_check[reaction-SIE4x4]
# Key 14 is not in dict_check[reaction-SIE4x4]
# Key 15 is not in dict_check[reaction-SIE4x4]
# Key 0 is not in dict_check[reaction-DARC]
# Key 1 is not in dict_check[reaction-DARC]
# Key 2 is not in dict_check[reaction-DARC]
# Key 3 is not in dict_check[reaction-DARC]
# Key 4 is not in dict_check[reaction-DARC]
# Key 5 is not in dict_check[reaction-DARC]
# Key 6 is not in dict_check[reaction-DARC]
# Key 7 is not in dict_check[reaction-DARC]
# Key 8 is not in dict_check[reaction-DARC]
# Key 9 is not in dict_check[reaction-DARC]
# Key 10 is not in dict_check[reaction-DARC]
# Key 11 is not in dict_check[reaction-DARC]
# Key 12 is not in dict_check[reaction-DARC]
# Key 13 is not in dict_check[reaction-DARC]
# Key ADDON-Ge is not in dict_check
# Key ADDON-As is not in dict_check
# Key ADDON-Se is not in dict_check
# Key ADDON-Sb is not in dict_check
# Key ADDON-Te is not in dict_check
# Key ADDON-I is not in dict_check
# Key ADDON-Bi is not in dict_check
# Key ADDON-Pb is not in dict_check
# Key reaction-ADDON is not in dict_check
# Key 0 is not in dict_check[reaction-HAL59]
# Key 1 is not in dict_check[reaction-HAL59]
# Key 2 is not in dict_check[reaction-HAL59]
# Key 3 is not in dict_check[reaction-HAL59]
# Key 4 is not in dict_check[reaction-HAL59]
# Key 5 is not in dict_check[reaction-HAL59]
# Key 6 is not in dict_check[reaction-HAL59]
# Key 7 is not in dict_check[reaction-HAL59]
# Key 8 is not in dict_check[reaction-HAL59]
# Key 9 is not in dict_check[reaction-HAL59]
# Key 10 is not in dict_check[reaction-HAL59]
# Key 11 is not in dict_check[reaction-HAL59]
# Key 12 is not in dict_check[reaction-HAL59]
# Key 13 is not in dict_check[reaction-HAL59]
# Key 14 is not in dict_check[reaction-HAL59]
# Key 15 is not in dict_check[reaction-HAL59]
# Key 16 is not in dict_check[reaction-HAL59]
# Key 17 is not in dict_check[reaction-HAL59]
# Key 18 is not in dict_check[reaction-HAL59]
# Key 19 is not in dict_check[reaction-HAL59]
# Key 20 is not in dict_check[reaction-HAL59]
# Key 21 is not in dict_check[reaction-HAL59]
# Key 22 is not in dict_check[reaction-HAL59]
# Key 23 is not in dict_check[reaction-HAL59]
# Key 24 is not in dict_check[reaction-HAL59]
# Key 25 is not in dict_check[reaction-HAL59]
# Key 26 is not in dict_check[reaction-HAL59]
# Key 27 is not in dict_check[reaction-HAL59]
# Key 28 is not in dict_check[reaction-HAL59]
# Key 29 is not in dict_check[reaction-HAL59]
# Key 30 is not in dict_check[reaction-HAL59]
# Key 31 is not in dict_check[reaction-HAL59]
# Key 32 is not in dict_check[reaction-HAL59]
# Key 33 is not in dict_check[reaction-HAL59]
# Key 34 is not in dict_check[reaction-HAL59]
# Key 35 is not in dict_check[reaction-HAL59]
# Key 36 is not in dict_check[reaction-HAL59]
# Key 37 is not in dict_check[reaction-HAL59]
# Key 38 is not in dict_check[reaction-HAL59]
# Key 39 is not in dict_check[reaction-HAL59]
# Key 40 is not in dict_check[reaction-HAL59]
# Key 41 is not in dict_check[reaction-HAL59]
# Key 42 is not in dict_check[reaction-HAL59]
# Key 43 is not in dict_check[reaction-HAL59]
# Key 44 is not in dict_check[reaction-HAL59]
# Key 45 is not in dict_check[reaction-HAL59]
# Key 46 is not in dict_check[reaction-HAL59]
# Key 47 is not in dict_check[reaction-HAL59]
# Key 48 is not in dict_check[reaction-HAL59]
# Key 49 is not in dict_check[reaction-HAL59]
# Key 50 is not in dict_check[reaction-HAL59]
# Key 51 is not in dict_check[reaction-HAL59]
# Key 52 is not in dict_check[reaction-HAL59]
# Key 53 is not in dict_check[reaction-HAL59]
# Key 54 is not in dict_check[reaction-HAL59]
# Key 55 is not in dict_check[reaction-HAL59]
# Key 56 is not in dict_check[reaction-HAL59]
# Key 57 is not in dict_check[reaction-HAL59]
# Key 58 is not in dict_check[reaction-HAL59]
# Key 0 is not in dict_check[reaction-ISO34]
# Key 1 is not in dict_check[reaction-ISO34]
# Key 2 is not in dict_check[reaction-ISO34]
# Key 3 is not in dict_check[reaction-ISO34]
# Key 4 is not in dict_check[reaction-ISO34]
# Key 5 is not in dict_check[reaction-ISO34]
# Key 6 is not in dict_check[reaction-ISO34]
# Key 7 is not in dict_check[reaction-ISO34]
# Key 8 is not in dict_check[reaction-ISO34]
# Key 9 is not in dict_check[reaction-ISO34]
# Key 10 is not in dict_check[reaction-ISO34]
# Key 11 is not in dict_check[reaction-ISO34]
# Key 12 is not in dict_check[reaction-ISO34]
# Key 13 is not in dict_check[reaction-ISO34]
# Key 14 is not in dict_check[reaction-ISO34]
# Key 15 is not in dict_check[reaction-ISO34]
# Key 16 is not in dict_check[reaction-ISO34]
# Key 17 is not in dict_check[reaction-ISO34]
# Key 18 is not in dict_check[reaction-ISO34]
# Key 19 is not in dict_check[reaction-ISO34]
# Key 20 is not in dict_check[reaction-ISO34]
# Key 21 is not in dict_check[reaction-ISO34]
# Key 22 is not in dict_check[reaction-ISO34]
# Key 23 is not in dict_check[reaction-ISO34]
# Key 24 is not in dict_check[reaction-ISO34]
# Key 25 is not in dict_check[reaction-ISO34]
# Key 26 is not in dict_check[reaction-ISO34]
# Key 27 is not in dict_check[reaction-ISO34]
# Key 28 is not in dict_check[reaction-ISO34]
# Key 29 is not in dict_check[reaction-ISO34]
# Key 30 is not in dict_check[reaction-ISO34]
# Key 31 is not in dict_check[reaction-ISO34]
# Key 32 is not in dict_check[reaction-ISO34]
# Key 33 is not in dict_check[reaction-ISO34]
# Key 0 is not in dict_check[reaction-BHPERI]
# Key 1 is not in dict_check[reaction-BHPERI]
# Key 2 is not in dict_check[reaction-BHPERI]
# Key 3 is not in dict_check[reaction-BHPERI]
# Key 4 is not in dict_check[reaction-BHPERI]
# Key 5 is not in dict_check[reaction-BHPERI]
# Key 6 is not in dict_check[reaction-BHPERI]
# Key 7 is not in dict_check[reaction-BHPERI]
# Key 8 is not in dict_check[reaction-BHPERI]
# Key 9 is not in dict_check[reaction-BHPERI]
# Key 10 is not in dict_check[reaction-BHPERI]
# Key 11 is not in dict_check[reaction-BHPERI]
# Key 12 is not in dict_check[reaction-BHPERI]
# Key 13 is not in dict_check[reaction-BHPERI]
# Key 14 is not in dict_check[reaction-BHPERI]
# Key 15 is not in dict_check[reaction-BHPERI]
# Key 16 is not in dict_check[reaction-BHPERI]
# Key 17 is not in dict_check[reaction-BHPERI]
# Key 18 is not in dict_check[reaction-BHPERI]
# Key 19 is not in dict_check[reaction-BHPERI]
# Key 20 is not in dict_check[reaction-BHPERI]
# Key 21 is not in dict_check[reaction-BHPERI]
# Key 22 is not in dict_check[reaction-BHPERI]
# Key 23 is not in dict_check[reaction-BHPERI]
# Key 24 is not in dict_check[reaction-BHPERI]
# Key 25 is not in dict_check[reaction-BHPERI]
# Key 0 is not in dict_check[reaction-ALK8]
# Key 1 is not in dict_check[reaction-ALK8]
# Key 2 is not in dict_check[reaction-ALK8]
# Key 3 is not in dict_check[reaction-ALK8]
# Key 4 is not in dict_check[reaction-ALK8]
# Key 5 is not in dict_check[reaction-ALK8]
# Key 6 is not in dict_check[reaction-ALK8]
# Key 7 is not in dict_check[reaction-ALK8]
# Key 0 is not in dict_check[reaction-G21EA]
# Key 1 is not in dict_check[reaction-G21EA]
# Key 2 is not in dict_check[reaction-G21EA]
# Key 3 is not in dict_check[reaction-G21EA]
# Key 4 is not in dict_check[reaction-G21EA]
# Key 5 is not in dict_check[reaction-G21EA]
# Key 6 is not in dict_check[reaction-G21EA]
# Key 7 is not in dict_check[reaction-G21EA]
# Key 8 is not in dict_check[reaction-G21EA]
# Key 9 is not in dict_check[reaction-G21EA]
# Key 10 is not in dict_check[reaction-G21EA]
# Key 11 is not in dict_check[reaction-G21EA]
# Key 12 is not in dict_check[reaction-G21EA]
# Key 13 is not in dict_check[reaction-G21EA]
# Key 14 is not in dict_check[reaction-G21EA]
# Key 15 is not in dict_check[reaction-G21EA]
# Key 16 is not in dict_check[reaction-G21EA]
# Key 17 is not in dict_check[reaction-G21EA]
# Key 18 is not in dict_check[reaction-G21EA]
# Key 19 is not in dict_check[reaction-G21EA]
# Key 20 is not in dict_check[reaction-G21EA]
# Key 21 is not in dict_check[reaction-G21EA]
# Key 22 is not in dict_check[reaction-G21EA]
# Key 23 is not in dict_check[reaction-G21EA]
# Key 24 is not in dict_check[reaction-G21EA]
# Key 0 is not in dict_check[reaction-UPU23]
# Key 1 is not in dict_check[reaction-UPU23]
# Key 2 is not in dict_check[reaction-UPU23]
# Key 3 is not in dict_check[reaction-UPU23]
# Key 4 is not in dict_check[reaction-UPU23]
# Key 5 is not in dict_check[reaction-UPU23]
# Key 6 is not in dict_check[reaction-UPU23]
# Key 7 is not in dict_check[reaction-UPU23]
# Key 8 is not in dict_check[reaction-UPU23]
# Key 9 is not in dict_check[reaction-UPU23]
# Key 10 is not in dict_check[reaction-UPU23]
# Key 11 is not in dict_check[reaction-UPU23]
# Key 12 is not in dict_check[reaction-UPU23]
# Key 13 is not in dict_check[reaction-UPU23]
# Key 14 is not in dict_check[reaction-UPU23]
# Key 15 is not in dict_check[reaction-UPU23]
# Key 16 is not in dict_check[reaction-UPU23]
# Key 17 is not in dict_check[reaction-UPU23]
# Key 18 is not in dict_check[reaction-UPU23]
# Key 19 is not in dict_check[reaction-UPU23]
# Key 20 is not in dict_check[reaction-UPU23]
# Key 21 is not in dict_check[reaction-UPU23]
# Key 22 is not in dict_check[reaction-UPU23]
# Key 0 is not in dict_check[reaction-PCONF21]
# Key 1 is not in dict_check[reaction-PCONF21]
# Key 2 is not in dict_check[reaction-PCONF21]
# Key 3 is not in dict_check[reaction-PCONF21]
# Key 4 is not in dict_check[reaction-PCONF21]
# Key 5 is not in dict_check[reaction-PCONF21]
# Key 6 is not in dict_check[reaction-PCONF21]
# Key 7 is not in dict_check[reaction-PCONF21]
# Key 8 is not in dict_check[reaction-PCONF21]
# Key 9 is not in dict_check[reaction-PCONF21]
# Key 10 is not in dict_check[reaction-PCONF21]
# Key 11 is not in dict_check[reaction-PCONF21]
# Key 12 is not in dict_check[reaction-PCONF21]
# Key 13 is not in dict_check[reaction-PCONF21]
# Key 14 is not in dict_check[reaction-PCONF21]
# Key 15 is not in dict_check[reaction-PCONF21]
# Key 16 is not in dict_check[reaction-PCONF21]
# Key 17 is not in dict_check[reaction-PCONF21]
# Key 0 is not in dict_check[reaction-BH76RC]
# Key 1 is not in dict_check[reaction-BH76RC]
# Key 2 is not in dict_check[reaction-BH76RC]
# Key 3 is not in dict_check[reaction-BH76RC]
# Key 4 is not in dict_check[reaction-BH76RC]
# Key 5 is not in dict_check[reaction-BH76RC]
# Key 6 is not in dict_check[reaction-BH76RC]
# Key 7 is not in dict_check[reaction-BH76RC]
# Key 8 is not in dict_check[reaction-BH76RC]
# Key 9 is not in dict_check[reaction-BH76RC]
# Key 10 is not in dict_check[reaction-BH76RC]
# Key 11 is not in dict_check[reaction-BH76RC]
# Key 12 is not in dict_check[reaction-BH76RC]
# Key 13 is not in dict_check[reaction-BH76RC]
# Key 14 is not in dict_check[reaction-BH76RC]
# Key 15 is not in dict_check[reaction-BH76RC]
# Key 16 is not in dict_check[reaction-BH76RC]
# Key 17 is not in dict_check[reaction-BH76RC]
# Key 18 is not in dict_check[reaction-BH76RC]
# Key 19 is not in dict_check[reaction-BH76RC]
# Key 20 is not in dict_check[reaction-BH76RC]
# Key 21 is not in dict_check[reaction-BH76RC]
# Key 22 is not in dict_check[reaction-BH76RC]
# Key 23 is not in dict_check[reaction-BH76RC]
# Key 24 is not in dict_check[reaction-BH76RC]
# Key 25 is not in dict_check[reaction-BH76RC]
# Key 26 is not in dict_check[reaction-BH76RC]
# Key 27 is not in dict_check[reaction-BH76RC]
# Key 28 is not in dict_check[reaction-BH76RC]
# Key 29 is not in dict_check[reaction-BH76RC]
# Key 0 is not in dict_check[reaction-FH51]
# Key 1 is not in dict_check[reaction-FH51]
# Key 2 is not in dict_check[reaction-FH51]
# Key 3 is not in dict_check[reaction-FH51]
# Key 4 is not in dict_check[reaction-FH51]
# Key 5 is not in dict_check[reaction-FH51]
# Key 6 is not in dict_check[reaction-FH51]
# Key 7 is not in dict_check[reaction-FH51]
# Key 8 is not in dict_check[reaction-FH51]
# Key 9 is not in dict_check[reaction-FH51]
# Key 10 is not in dict_check[reaction-FH51]
# Key 11 is not in dict_check[reaction-FH51]
# Key 12 is not in dict_check[reaction-FH51]
# Key 13 is not in dict_check[reaction-FH51]
# Key 14 is not in dict_check[reaction-FH51]
# Key 15 is not in dict_check[reaction-FH51]
# Key 16 is not in dict_check[reaction-FH51]
# Key 17 is not in dict_check[reaction-FH51]
# Key 18 is not in dict_check[reaction-FH51]
# Key 19 is not in dict_check[reaction-FH51]
# Key 20 is not in dict_check[reaction-FH51]
# Key 21 is not in dict_check[reaction-FH51]
# Key 22 is not in dict_check[reaction-FH51]
# Key 23 is not in dict_check[reaction-FH51]
# Key 24 is not in dict_check[reaction-FH51]
# Key 25 is not in dict_check[reaction-FH51]
# Key 26 is not in dict_check[reaction-FH51]
# Key 27 is not in dict_check[reaction-FH51]
# Key 28 is not in dict_check[reaction-FH51]
# Key 29 is not in dict_check[reaction-FH51]
# Key 30 is not in dict_check[reaction-FH51]
# Key 31 is not in dict_check[reaction-FH51]
# Key 32 is not in dict_check[reaction-FH51]
# Key 33 is not in dict_check[reaction-FH51]
# Key 34 is not in dict_check[reaction-FH51]
# Key 35 is not in dict_check[reaction-FH51]
# Key 36 is not in dict_check[reaction-FH51]
# Key 37 is not in dict_check[reaction-FH51]
# Key 38 is not in dict_check[reaction-FH51]
# Key 39 is not in dict_check[reaction-FH51]
# Key 40 is not in dict_check[reaction-FH51]
# Key 41 is not in dict_check[reaction-FH51]
# Key 42 is not in dict_check[reaction-FH51]
# Key 43 is not in dict_check[reaction-FH51]
# Key 44 is not in dict_check[reaction-FH51]
# Key 45 is not in dict_check[reaction-FH51]
# Key 46 is not in dict_check[reaction-FH51]
# Key 47 is not in dict_check[reaction-FH51]
# Key 48 is not in dict_check[reaction-FH51]
# Key 49 is not in dict_check[reaction-FH51]
# Key 50 is not in dict_check[reaction-FH51]
# Key 0 is not in dict_check[reaction-YBDE18]
# Key 1 is not in dict_check[reaction-YBDE18]
# Key 2 is not in dict_check[reaction-YBDE18]
# Key 3 is not in dict_check[reaction-YBDE18]
# Key 4 is not in dict_check[reaction-YBDE18]
# Key 5 is not in dict_check[reaction-YBDE18]
# Key 6 is not in dict_check[reaction-YBDE18]
# Key 7 is not in dict_check[reaction-YBDE18]
# Key 8 is not in dict_check[reaction-YBDE18]
# Key 9 is not in dict_check[reaction-YBDE18]
# Key 10 is not in dict_check[reaction-YBDE18]
# Key 11 is not in dict_check[reaction-YBDE18]
# Key 12 is not in dict_check[reaction-YBDE18]
# Key 13 is not in dict_check[reaction-YBDE18]
# Key 14 is not in dict_check[reaction-YBDE18]
# Key 15 is not in dict_check[reaction-YBDE18]
# Key 16 is not in dict_check[reaction-YBDE18]
# Key 17 is not in dict_check[reaction-YBDE18]
# Key 0 is not in dict_check[reaction-PArel]
# Key 1 is not in dict_check[reaction-PArel]
# Key 2 is not in dict_check[reaction-PArel]
# Key 3 is not in dict_check[reaction-PArel]
# Key 4 is not in dict_check[reaction-PArel]
# Key 5 is not in dict_check[reaction-PArel]
# Key 6 is not in dict_check[reaction-PArel]
# Key 7 is not in dict_check[reaction-PArel]
# Key 8 is not in dict_check[reaction-PArel]
# Key 9 is not in dict_check[reaction-PArel]
# Key 10 is not in dict_check[reaction-PArel]
# Key 11 is not in dict_check[reaction-PArel]
# Key 12 is not in dict_check[reaction-PArel]
# Key 13 is not in dict_check[reaction-PArel]
# Key 14 is not in dict_check[reaction-PArel]
# Key 15 is not in dict_check[reaction-PArel]
# Key 16 is not in dict_check[reaction-PArel]
# Key 17 is not in dict_check[reaction-PArel]
# Key 18 is not in dict_check[reaction-PArel]
# Key 19 is not in dict_check[reaction-PArel]
# Key 0 is not in dict_check[reaction-IDISP]
# Key 1 is not in dict_check[reaction-IDISP]
# Key 2 is not in dict_check[reaction-IDISP]
# Key 3 is not in dict_check[reaction-IDISP]
# Key 4 is not in dict_check[reaction-IDISP]
# Key 5 is not in dict_check[reaction-IDISP]
# Key 0 is not in dict_check[reaction-Amino20x4]
# Key 1 is not in dict_check[reaction-Amino20x4]
# Key 2 is not in dict_check[reaction-Amino20x4]
# Key 3 is not in dict_check[reaction-Amino20x4]
# Key 4 is not in dict_check[reaction-Amino20x4]
# Key 5 is not in dict_check[reaction-Amino20x4]
# Key 6 is not in dict_check[reaction-Amino20x4]
# Key 7 is not in dict_check[reaction-Amino20x4]
# Key 8 is not in dict_check[reaction-Amino20x4]
# Key 9 is not in dict_check[reaction-Amino20x4]
# Key 10 is not in dict_check[reaction-Amino20x4]
# Key 11 is not in dict_check[reaction-Amino20x4]
# Key 12 is not in dict_check[reaction-Amino20x4]
# Key 13 is not in dict_check[reaction-Amino20x4]
# Key 14 is not in dict_check[reaction-Amino20x4]
# Key 15 is not in dict_check[reaction-Amino20x4]
# Key 16 is not in dict_check[reaction-Amino20x4]
# Key 17 is not in dict_check[reaction-Amino20x4]
# Key 18 is not in dict_check[reaction-Amino20x4]
# Key 19 is not in dict_check[reaction-Amino20x4]
# Key 20 is not in dict_check[reaction-Amino20x4]
# Key 21 is not in dict_check[reaction-Amino20x4]
# Key 22 is not in dict_check[reaction-Amino20x4]
# Key 23 is not in dict_check[reaction-Amino20x4]
# Key 24 is not in dict_check[reaction-Amino20x4]
# Key 25 is not in dict_check[reaction-Amino20x4]
# Key 26 is not in dict_check[reaction-Amino20x4]
# Key 27 is not in dict_check[reaction-Amino20x4]
# Key 28 is not in dict_check[reaction-Amino20x4]
# Key 29 is not in dict_check[reaction-Amino20x4]
# Key 30 is not in dict_check[reaction-Amino20x4]
# Key 31 is not in dict_check[reaction-Amino20x4]
# Key 32 is not in dict_check[reaction-Amino20x4]
# Key 33 is not in dict_check[reaction-Amino20x4]
# Key 34 is not in dict_check[reaction-Amino20x4]
# Key 35 is not in dict_check[reaction-Amino20x4]
# Key 36 is not in dict_check[reaction-Amino20x4]
# Key 37 is not in dict_check[reaction-Amino20x4]
# Key 38 is not in dict_check[reaction-Amino20x4]
# Key 39 is not in dict_check[reaction-Amino20x4]
# Key 40 is not in dict_check[reaction-Amino20x4]
# Key 41 is not in dict_check[reaction-Amino20x4]
# Key 42 is not in dict_check[reaction-Amino20x4]
# Key 43 is not in dict_check[reaction-Amino20x4]
# Key 44 is not in dict_check[reaction-Amino20x4]
# Key 45 is not in dict_check[reaction-Amino20x4]
# Key 46 is not in dict_check[reaction-Amino20x4]
# Key 47 is not in dict_check[reaction-Amino20x4]
# Key 48 is not in dict_check[reaction-Amino20x4]
# Key 49 is not in dict_check[reaction-Amino20x4]
# Key 50 is not in dict_check[reaction-Amino20x4]
# Key 51 is not in dict_check[reaction-Amino20x4]
# Key 52 is not in dict_check[reaction-Amino20x4]
# Key 53 is not in dict_check[reaction-Amino20x4]
# Key 54 is not in dict_check[reaction-Amino20x4]
# Key 55 is not in dict_check[reaction-Amino20x4]
# Key 56 is not in dict_check[reaction-Amino20x4]
# Key 57 is not in dict_check[reaction-Amino20x4]
# Key 58 is not in dict_check[reaction-Amino20x4]
# Key 59 is not in dict_check[reaction-Amino20x4]
# Key 60 is not in dict_check[reaction-Amino20x4]
# Key 61 is not in dict_check[reaction-Amino20x4]
# Key 62 is not in dict_check[reaction-Amino20x4]
# Key 63 is not in dict_check[reaction-Amino20x4]
# Key 64 is not in dict_check[reaction-Amino20x4]
# Key 65 is not in dict_check[reaction-Amino20x4]
# Key 66 is not in dict_check[reaction-Amino20x4]
# Key 67 is not in dict_check[reaction-Amino20x4]
# Key 68 is not in dict_check[reaction-Amino20x4]
# Key 69 is not in dict_check[reaction-Amino20x4]
# Key 70 is not in dict_check[reaction-Amino20x4]
# Key 71 is not in dict_check[reaction-Amino20x4]
# Key 72 is not in dict_check[reaction-Amino20x4]
# Key 73 is not in dict_check[reaction-Amino20x4]
# Key 74 is not in dict_check[reaction-Amino20x4]
# Key 75 is not in dict_check[reaction-Amino20x4]
# Key 76 is not in dict_check[reaction-Amino20x4]
# Key 77 is not in dict_check[reaction-Amino20x4]
# Key 78 is not in dict_check[reaction-Amino20x4]
# Key 79 is not in dict_check[reaction-Amino20x4]
# Key 0 is not in dict_check[reaction-ADIM6]
# Key 1 is not in dict_check[reaction-ADIM6]
# Key 2 is not in dict_check[reaction-ADIM6]
# Key 3 is not in dict_check[reaction-ADIM6]
# Key 4 is not in dict_check[reaction-ADIM6]
# Key 5 is not in dict_check[reaction-ADIM6]
# Key 0 is not in dict_check[reaction-ALKBDE10]
# Key 1 is not in dict_check[reaction-ALKBDE10]
# Key 2 is not in dict_check[reaction-ALKBDE10]
# Key 3 is not in dict_check[reaction-ALKBDE10]
# Key 4 is not in dict_check[reaction-ALKBDE10]
# Key 5 is not in dict_check[reaction-ALKBDE10]
# Key 6 is not in dict_check[reaction-ALKBDE10]
# Key 7 is not in dict_check[reaction-ALKBDE10]
# Key 8 is not in dict_check[reaction-ALKBDE10]
# Key 9 is not in dict_check[reaction-ALKBDE10]
# Key 0 is not in dict_check[reaction-ISOL24]
# Key 1 is not in dict_check[reaction-ISOL24]
# Key 2 is not in dict_check[reaction-ISOL24]
# Key 3 is not in dict_check[reaction-ISOL24]
# Key 4 is not in dict_check[reaction-ISOL24]
# Key 5 is not in dict_check[reaction-ISOL24]
# Key 6 is not in dict_check[reaction-ISOL24]
# Key 7 is not in dict_check[reaction-ISOL24]
# Key 8 is not in dict_check[reaction-ISOL24]
# Key 9 is not in dict_check[reaction-ISOL24]
# Key 10 is not in dict_check[reaction-ISOL24]
# Key 11 is not in dict_check[reaction-ISOL24]
# Key 12 is not in dict_check[reaction-ISOL24]
# Key 13 is not in dict_check[reaction-ISOL24]
# Key 14 is not in dict_check[reaction-ISOL24]
# Key 15 is not in dict_check[reaction-ISOL24]
# Key 16 is not in dict_check[reaction-ISOL24]
# Key 17 is not in dict_check[reaction-ISOL24]
# Key 18 is not in dict_check[reaction-ISOL24]
# Key 19 is not in dict_check[reaction-ISOL24]
# Key 20 is not in dict_check[reaction-ISOL24]
# Key 21 is not in dict_check[reaction-ISOL24]
# Key 22 is not in dict_check[reaction-ISOL24]
# Key 23 is not in dict_check[reaction-ISOL24]
# Key 0 is not in dict_check[reaction-RSE43]
# Key 1 is not in dict_check[reaction-RSE43]
# Key 2 is not in dict_check[reaction-RSE43]
# Key 3 is not in dict_check[reaction-RSE43]
# Key 4 is not in dict_check[reaction-RSE43]
# Key 5 is not in dict_check[reaction-RSE43]
# Key 6 is not in dict_check[reaction-RSE43]
# Key 7 is not in dict_check[reaction-RSE43]
# Key 8 is not in dict_check[reaction-RSE43]
# Key 9 is not in dict_check[reaction-RSE43]
# Key 10 is not in dict_check[reaction-RSE43]
# Key 11 is not in dict_check[reaction-RSE43]
# Key 12 is not in dict_check[reaction-RSE43]
# Key 13 is not in dict_check[reaction-RSE43]
# Key 14 is not in dict_check[reaction-RSE43]
# Key 15 is not in dict_check[reaction-RSE43]
# Key 16 is not in dict_check[reaction-RSE43]
# Key 17 is not in dict_check[reaction-RSE43]
# Key 18 is not in dict_check[reaction-RSE43]
# Key 19 is not in dict_check[reaction-RSE43]
# Key 20 is not in dict_check[reaction-RSE43]
# Key 21 is not in dict_check[reaction-RSE43]
# Key 22 is not in dict_check[reaction-RSE43]
# Key 23 is not in dict_check[reaction-RSE43]
# Key 24 is not in dict_check[reaction-RSE43]
# Key 25 is not in dict_check[reaction-RSE43]
# Key 26 is not in dict_check[reaction-RSE43]
# Key 27 is not in dict_check[reaction-RSE43]
# Key 28 is not in dict_check[reaction-RSE43]
# Key 29 is not in dict_check[reaction-RSE43]
# Key 30 is not in dict_check[reaction-RSE43]
# Key 31 is not in dict_check[reaction-RSE43]
# Key 32 is not in dict_check[reaction-RSE43]
# Key 33 is not in dict_check[reaction-RSE43]
# Key 34 is not in dict_check[reaction-RSE43]
# Key 35 is not in dict_check[reaction-RSE43]
# Key 36 is not in dict_check[reaction-RSE43]
# Key 37 is not in dict_check[reaction-RSE43]
# Key 38 is not in dict_check[reaction-RSE43]
# Key 39 is not in dict_check[reaction-RSE43]
# Key 40 is not in dict_check[reaction-RSE43]
# Key 41 is not in dict_check[reaction-RSE43]
# Key 42 is not in dict_check[reaction-RSE43]
# Key 0 is not in dict_check[reaction-G21IP]
# Key 1 is not in dict_check[reaction-G21IP]
# Key 2 is not in dict_check[reaction-G21IP]
# Key 3 is not in dict_check[reaction-G21IP]
# Key 4 is not in dict_check[reaction-G21IP]
# Key 5 is not in dict_check[reaction-G21IP]
# Key 6 is not in dict_check[reaction-G21IP]
# Key 7 is not in dict_check[reaction-G21IP]
# Key 8 is not in dict_check[reaction-G21IP]
# Key 9 is not in dict_check[reaction-G21IP]
# Key 10 is not in dict_check[reaction-G21IP]
# Key 11 is not in dict_check[reaction-G21IP]
# Key 12 is not in dict_check[reaction-G21IP]
# Key 13 is not in dict_check[reaction-G21IP]
# Key 14 is not in dict_check[reaction-G21IP]
# Key 15 is not in dict_check[reaction-G21IP]
# Key 16 is not in dict_check[reaction-G21IP]
# Key 17 is not in dict_check[reaction-G21IP]
# Key 18 is not in dict_check[reaction-G21IP]
# Key 19 is not in dict_check[reaction-G21IP]
# Key 20 is not in dict_check[reaction-G21IP]
# Key 21 is not in dict_check[reaction-G21IP]
# Key 22 is not in dict_check[reaction-G21IP]
# Key 23 is not in dict_check[reaction-G21IP]
# Key 24 is not in dict_check[reaction-G21IP]
# Key 25 is not in dict_check[reaction-G21IP]
# Key 26 is not in dict_check[reaction-G21IP]
# Key 27 is not in dict_check[reaction-G21IP]
# Key 28 is not in dict_check[reaction-G21IP]
# Key 29 is not in dict_check[reaction-G21IP]
# Key 30 is not in dict_check[reaction-G21IP]
# Key 31 is not in dict_check[reaction-G21IP]
# Key 32 is not in dict_check[reaction-G21IP]
# Key 33 is not in dict_check[reaction-G21IP]
# Key 34 is not in dict_check[reaction-G21IP]
# Key 35 is not in dict_check[reaction-G21IP]
# Key 0 is not in dict_check[reaction-BHROT27]
# Key 1 is not in dict_check[reaction-BHROT27]
# Key 2 is not in dict_check[reaction-BHROT27]
# Key 3 is not in dict_check[reaction-BHROT27]
# Key 4 is not in dict_check[reaction-BHROT27]
# Key 5 is not in dict_check[reaction-BHROT27]
# Key 6 is not in dict_check[reaction-BHROT27]
# Key 7 is not in dict_check[reaction-BHROT27]
# Key 8 is not in dict_check[reaction-BHROT27]
# Key 9 is not in dict_check[reaction-BHROT27]
# Key 10 is not in dict_check[reaction-BHROT27]
# Key 11 is not in dict_check[reaction-BHROT27]
# Key 12 is not in dict_check[reaction-BHROT27]
# Key 13 is not in dict_check[reaction-BHROT27]
# Key 14 is not in dict_check[reaction-BHROT27]
# Key 15 is not in dict_check[reaction-BHROT27]
# Key 16 is not in dict_check[reaction-BHROT27]
# Key 17 is not in dict_check[reaction-BHROT27]
# Key 18 is not in dict_check[reaction-BHROT27]
# Key 19 is not in dict_check[reaction-BHROT27]
# Key 20 is not in dict_check[reaction-BHROT27]
# Key 21 is not in dict_check[reaction-BHROT27]
# Key 22 is not in dict_check[reaction-BHROT27]
# Key 23 is not in dict_check[reaction-BHROT27]
# Key 24 is not in dict_check[reaction-BHROT27]
# Key 25 is not in dict_check[reaction-BHROT27]
# Key 26 is not in dict_check[reaction-BHROT27]
# Key 0 is not in dict_check[reaction-W4_11]
# Key 1 is not in dict_check[reaction-W4_11]
# Key 2 is not in dict_check[reaction-W4_11]
# Key 3 is not in dict_check[reaction-W4_11]
# Key 4 is not in dict_check[reaction-W4_11]
# Key 5 is not in dict_check[reaction-W4_11]
# Key 6 is not in dict_check[reaction-W4_11]
# Key 7 is not in dict_check[reaction-W4_11]
# Key 8 is not in dict_check[reaction-W4_11]
# Key 9 is not in dict_check[reaction-W4_11]
# Key 10 is not in dict_check[reaction-W4_11]
# Key 11 is not in dict_check[reaction-W4_11]
# Key 12 is not in dict_check[reaction-W4_11]
# Key 13 is not in dict_check[reaction-W4_11]
# Key 14 is not in dict_check[reaction-W4_11]
# Key 15 is not in dict_check[reaction-W4_11]
# Key 16 is not in dict_check[reaction-W4_11]
# Key 17 is not in dict_check[reaction-W4_11]
# Key 18 is not in dict_check[reaction-W4_11]
# Key 19 is not in dict_check[reaction-W4_11]
# Key 20 is not in dict_check[reaction-W4_11]
# Key 21 is not in dict_check[reaction-W4_11]
# Key 22 is not in dict_check[reaction-W4_11]
# Key 23 is not in dict_check[reaction-W4_11]
# Key 24 is not in dict_check[reaction-W4_11]
# Key 25 is not in dict_check[reaction-W4_11]
# Key 26 is not in dict_check[reaction-W4_11]
# Key 27 is not in dict_check[reaction-W4_11]
# Key 28 is not in dict_check[reaction-W4_11]
# Key 29 is not in dict_check[reaction-W4_11]
# Key 30 is not in dict_check[reaction-W4_11]
# Key 31 is not in dict_check[reaction-W4_11]
# Key 32 is not in dict_check[reaction-W4_11]
# Key 33 is not in dict_check[reaction-W4_11]
# Key 34 is not in dict_check[reaction-W4_11]
# Key 35 is not in dict_check[reaction-W4_11]
# Key 36 is not in dict_check[reaction-W4_11]
# Key 37 is not in dict_check[reaction-W4_11]
# Key 38 is not in dict_check[reaction-W4_11]
# Key 39 is not in dict_check[reaction-W4_11]
# Key 40 is not in dict_check[reaction-W4_11]
# Key 41 is not in dict_check[reaction-W4_11]
# Key 42 is not in dict_check[reaction-W4_11]
# Key 43 is not in dict_check[reaction-W4_11]
# Key 44 is not in dict_check[reaction-W4_11]
# Key 45 is not in dict_check[reaction-W4_11]
# Key 46 is not in dict_check[reaction-W4_11]
# Key 47 is not in dict_check[reaction-W4_11]
# Key 48 is not in dict_check[reaction-W4_11]
# Key 49 is not in dict_check[reaction-W4_11]
# Key 50 is not in dict_check[reaction-W4_11]
# Key 51 is not in dict_check[reaction-W4_11]
# Key 52 is not in dict_check[reaction-W4_11]
# Key 53 is not in dict_check[reaction-W4_11]
# Key 54 is not in dict_check[reaction-W4_11]
# Key 55 is not in dict_check[reaction-W4_11]
# Key 56 is not in dict_check[reaction-W4_11]
# Key 57 is not in dict_check[reaction-W4_11]
# Key 58 is not in dict_check[reaction-W4_11]
# Key 59 is not in dict_check[reaction-W4_11]
# Key 60 is not in dict_check[reaction-W4_11]
# Key 61 is not in dict_check[reaction-W4_11]
# Key 62 is not in dict_check[reaction-W4_11]
# Key 63 is not in dict_check[reaction-W4_11]
# Key 64 is not in dict_check[reaction-W4_11]
# Key 65 is not in dict_check[reaction-W4_11]
# Key 66 is not in dict_check[reaction-W4_11]
# Key 67 is not in dict_check[reaction-W4_11]
# Key 68 is not in dict_check[reaction-W4_11]
# Key 69 is not in dict_check[reaction-W4_11]
# Key 70 is not in dict_check[reaction-W4_11]
# Key 71 is not in dict_check[reaction-W4_11]
# Key 72 is not in dict_check[reaction-W4_11]
# Key 73 is not in dict_check[reaction-W4_11]
# Key 74 is not in dict_check[reaction-W4_11]
# Key 75 is not in dict_check[reaction-W4_11]
# Key 76 is not in dict_check[reaction-W4_11]
# Key 77 is not in dict_check[reaction-W4_11]
# Key 78 is not in dict_check[reaction-W4_11]
# Key 79 is not in dict_check[reaction-W4_11]
# Key 80 is not in dict_check[reaction-W4_11]
# Key 81 is not in dict_check[reaction-W4_11]
# Key 82 is not in dict_check[reaction-W4_11]
# Key 83 is not in dict_check[reaction-W4_11]
# Key 84 is not in dict_check[reaction-W4_11]
# Key 85 is not in dict_check[reaction-W4_11]
# Key 86 is not in dict_check[reaction-W4_11]
# Key 87 is not in dict_check[reaction-W4_11]
# Key 88 is not in dict_check[reaction-W4_11]
# Key 89 is not in dict_check[reaction-W4_11]
# Key 90 is not in dict_check[reaction-W4_11]
# Key 91 is not in dict_check[reaction-W4_11]
# Key 92 is not in dict_check[reaction-W4_11]
# Key 93 is not in dict_check[reaction-W4_11]
# Key 94 is not in dict_check[reaction-W4_11]
# Key 95 is not in dict_check[reaction-W4_11]
# Key 96 is not in dict_check[reaction-W4_11]
# Key 97 is not in dict_check[reaction-W4_11]
# Key 98 is not in dict_check[reaction-W4_11]
# Key 99 is not in dict_check[reaction-W4_11]
# Key 100 is not in dict_check[reaction-W4_11]
# Key 101 is not in dict_check[reaction-W4_11]
# Key 102 is not in dict_check[reaction-W4_11]
# Key 103 is not in dict_check[reaction-W4_11]
# Key 104 is not in dict_check[reaction-W4_11]
# Key 105 is not in dict_check[reaction-W4_11]
# Key 106 is not in dict_check[reaction-W4_11]
# Key 107 is not in dict_check[reaction-W4_11]
# Key 108 is not in dict_check[reaction-W4_11]
# Key 109 is not in dict_check[reaction-W4_11]
# Key 110 is not in dict_check[reaction-W4_11]
# Key 111 is not in dict_check[reaction-W4_11]
# Key 112 is not in dict_check[reaction-W4_11]
# Key 113 is not in dict_check[reaction-W4_11]
# Key 114 is not in dict_check[reaction-W4_11]
# Key 115 is not in dict_check[reaction-W4_11]
# Key 116 is not in dict_check[reaction-W4_11]
# Key 117 is not in dict_check[reaction-W4_11]
# Key 118 is not in dict_check[reaction-W4_11]
# Key 119 is not in dict_check[reaction-W4_11]
# Key 120 is not in dict_check[reaction-W4_11]
# Key 121 is not in dict_check[reaction-W4_11]
# Key 122 is not in dict_check[reaction-W4_11]
# Key 123 is not in dict_check[reaction-W4_11]
# Key 124 is not in dict_check[reaction-W4_11]
# Key 125 is not in dict_check[reaction-W4_11]
# Key 126 is not in dict_check[reaction-W4_11]
# Key 127 is not in dict_check[reaction-W4_11]
# Key 128 is not in dict_check[reaction-W4_11]
# Key 129 is not in dict_check[reaction-W4_11]
# Key 130 is not in dict_check[reaction-W4_11]
# Key 131 is not in dict_check[reaction-W4_11]
# Key 132 is not in dict_check[reaction-W4_11]
# Key 133 is not in dict_check[reaction-W4_11]
# Key 134 is not in dict_check[reaction-W4_11]
# Key 135 is not in dict_check[reaction-W4_11]
# Key 136 is not in dict_check[reaction-W4_11]
# Key 137 is not in dict_check[reaction-W4_11]
# Key 138 is not in dict_check[reaction-W4_11]
# Key 139 is not in dict_check[reaction-W4_11]
# Key 0 is not in dict_check[reaction-C60ISO]
# Key 1 is not in dict_check[reaction-C60ISO]
# Key 2 is not in dict_check[reaction-C60ISO]
# Key 3 is not in dict_check[reaction-C60ISO]
# Key 4 is not in dict_check[reaction-C60ISO]
# Key 5 is not in dict_check[reaction-C60ISO]
# Key 6 is not in dict_check[reaction-C60ISO]
# Key 7 is not in dict_check[reaction-C60ISO]
# Key 8 is not in dict_check[reaction-C60ISO]
# Key 0 is not in dict_check[reaction-HEAVYSB11]
# Key 1 is not in dict_check[reaction-HEAVYSB11]
# Key 2 is not in dict_check[reaction-HEAVYSB11]
# Key 3 is not in dict_check[reaction-HEAVYSB11]
# Key 4 is not in dict_check[reaction-HEAVYSB11]
# Key 5 is not in dict_check[reaction-HEAVYSB11]
# Key 6 is not in dict_check[reaction-HEAVYSB11]
# Key 7 is not in dict_check[reaction-HEAVYSB11]
# Key 8 is not in dict_check[reaction-HEAVYSB11]
# Key 9 is not in dict_check[reaction-HEAVYSB11]
# Key 10 is not in dict_check[reaction-HEAVYSB11]
# Key 0 is not in dict_check[reaction-DIPCS10]
# Key 1 is not in dict_check[reaction-DIPCS10]
# Key 2 is not in dict_check[reaction-DIPCS10]
# Key 3 is not in dict_check[reaction-DIPCS10]
# Key 4 is not in dict_check[reaction-DIPCS10]
# Key 5 is not in dict_check[reaction-DIPCS10]
# Key 6 is not in dict_check[reaction-DIPCS10]
# Key 7 is not in dict_check[reaction-DIPCS10]
# Key 8 is not in dict_check[reaction-DIPCS10]
# Key 9 is not in dict_check[reaction-DIPCS10]
# Key 0 is not in dict_check[reaction-CDIE20]
# Key 1 is not in dict_check[reaction-CDIE20]
# Key 2 is not in dict_check[reaction-CDIE20]
# Key 3 is not in dict_check[reaction-CDIE20]
# Key 4 is not in dict_check[reaction-CDIE20]
# Key 5 is not in dict_check[reaction-CDIE20]
# Key 6 is not in dict_check[reaction-CDIE20]
# Key 7 is not in dict_check[reaction-CDIE20]
# Key 8 is not in dict_check[reaction-CDIE20]
# Key 9 is not in dict_check[reaction-CDIE20]
# Key 10 is not in dict_check[reaction-CDIE20]
# Key 11 is not in dict_check[reaction-CDIE20]
# Key 12 is not in dict_check[reaction-CDIE20]
# Key 13 is not in dict_check[reaction-CDIE20]
# Key 14 is not in dict_check[reaction-CDIE20]
# Key 15 is not in dict_check[reaction-CDIE20]
# Key 16 is not in dict_check[reaction-CDIE20]
# Key 17 is not in dict_check[reaction-CDIE20]
# Key 18 is not in dict_check[reaction-CDIE20]
# Key 19 is not in dict_check[reaction-CDIE20]
# Key 0 is not in dict_check[reaction-PX13]
# Key 1 is not in dict_check[reaction-PX13]
# Key 2 is not in dict_check[reaction-PX13]
# Key 3 is not in dict_check[reaction-PX13]
# Key 4 is not in dict_check[reaction-PX13]
# Key 5 is not in dict_check[reaction-PX13]
# Key 6 is not in dict_check[reaction-PX13]
# Key 7 is not in dict_check[reaction-PX13]
# Key 8 is not in dict_check[reaction-PX13]
# Key 9 is not in dict_check[reaction-PX13]
# Key 10 is not in dict_check[reaction-PX13]
# Key 11 is not in dict_check[reaction-PX13]
# Key 12 is not in dict_check[reaction-PX13]
# Key 0 is not in dict_check[reaction-AL2X6]
# Key 1 is not in dict_check[reaction-AL2X6]
# Key 2 is not in dict_check[reaction-AL2X6]
# Key 3 is not in dict_check[reaction-AL2X6]
# Key 4 is not in dict_check[reaction-AL2X6]
# Key 5 is not in dict_check[reaction-AL2X6]
# Key 0 is not in dict_check[reaction-BHDIV10]
# Key 1 is not in dict_check[reaction-BHDIV10]
# Key 2 is not in dict_check[reaction-BHDIV10]
# Key 3 is not in dict_check[reaction-BHDIV10]
# Key 4 is not in dict_check[reaction-BHDIV10]
# Key 5 is not in dict_check[reaction-BHDIV10]
# Key 6 is not in dict_check[reaction-BHDIV10]
# Key 7 is not in dict_check[reaction-BHDIV10]
# Key 8 is not in dict_check[reaction-BHDIV10]
# Key 9 is not in dict_check[reaction-BHDIV10]
# Key 0 is not in dict_check[reaction-CHB6]
# Key 1 is not in dict_check[reaction-CHB6]
# Key 2 is not in dict_check[reaction-CHB6]
# Key 3 is not in dict_check[reaction-CHB6]
# Key 4 is not in dict_check[reaction-CHB6]
# Key 5 is not in dict_check[reaction-CHB6]
# Key 0 is not in dict_check[reaction-AHB21]
# Key 1 is not in dict_check[reaction-AHB21]
# Key 2 is not in dict_check[reaction-AHB21]
# Key 3 is not in dict_check[reaction-AHB21]
# Key 4 is not in dict_check[reaction-AHB21]
# Key 5 is not in dict_check[reaction-AHB21]
# Key 6 is not in dict_check[reaction-AHB21]
# Key 7 is not in dict_check[reaction-AHB21]
# Key 8 is not in dict_check[reaction-AHB21]
# Key 9 is not in dict_check[reaction-AHB21]
# Key 10 is not in dict_check[reaction-AHB21]
# Key 11 is not in dict_check[reaction-AHB21]
# Key 12 is not in dict_check[reaction-AHB21]
# Key 13 is not in dict_check[reaction-AHB21]
# Key 14 is not in dict_check[reaction-AHB21]
# Key 15 is not in dict_check[reaction-AHB21]
# Key 16 is not in dict_check[reaction-AHB21]
# Key 17 is not in dict_check[reaction-AHB21]
# Key 18 is not in dict_check[reaction-AHB21]
# Key 19 is not in dict_check[reaction-AHB21]
# Key 20 is not in dict_check[reaction-AHB21]
# ...
# Key 1 is not in dict_check[reaction-ACONF]
# Key 2 is not in dict_check[reaction-ACONF]
# Key 3 is not in dict_check[reaction-ACONF]
# Key 4 is not in dict_check[reaction-ACONF]
# Key 5 is not in dict_check[reaction-ACONF]
# Key 6 is not in dict_check[reaction-ACONF]
# Key 7 is not in dict_check[reaction-ACONF]
# Key 8 is not in dict_check[reaction-ACONF]
# Key 9 is not in dict_check[reaction-ACONF]
# Key 10 is not in dict_check[reaction-ACONF]
# Key 11 is not in dict_check[reaction-ACONF]
# Key 12 is not in dict_check[reaction-ACONF]
# Key 13 is not in dict_check[reaction-ACONF]
# Key 14 is not in dict_check[reaction-ACONF]
# Key 0 is not in dict_check[reaction-BH76]
# Key 1 is not in dict_check[reaction-BH76]
# Key 2 is not in dict_check[reaction-BH76]
# Key 3 is not in dict_check[reaction-BH76]
# Key 4 is not in dict_check[reaction-BH76]
# Key 5 is not in dict_check[reaction-BH76]
# Key 6 is not in dict_check[reaction-BH76]
# Key 7 is not in dict_check[reaction-BH76]
# Key 8 is not in dict_check[reaction-BH76]
# Key 9 is not in dict_check[reaction-BH76]
# Key 10 is not in dict_check[reaction-BH76]
# Key 11 is not in dict_check[reaction-BH76]
# Key 12 is not in dict_check[reaction-BH76]
# Key 13 is not in dict_check[reaction-BH76]
# Key 14 is not in dict_check[reaction-BH76]
# Key 15 is not in dict_check[reaction-BH76]
# Key 16 is not in dict_check[reaction-BH76]
# Key 17 is not in dict_check[reaction-BH76]
# Key 18 is not in dict_check[reaction-BH76]
# Key 19 is not in dict_check[reaction-BH76]
# Key 20 is not in dict_check[reaction-BH76]
# Key 21 is not in dict_check[reaction-BH76]
# Key 22 is not in dict_check[reaction-BH76]
# Key 23 is not in dict_check[reaction-BH76]
# Key 24 is not in dict_check[reaction-BH76]
# Key 25 is not in dict_check[reaction-BH76]
# Key 26 is not in dict_check[reaction-BH76]
# Key 27 is not in dict_check[reaction-BH76]
# Key 28 is not in dict_check[reaction-BH76]
# Key 29 is not in dict_check[reaction-BH76]
# Key 30 is not in dict_check[reaction-BH76]
# Key 31 is not in dict_check[reaction-BH76]
# Key 32 is not in dict_check[reaction-BH76]
# Key 33 is not in dict_check[reaction-BH76]
# Key 34 is not in dict_check[reaction-BH76]
# Key 35 is not in dict_check[reaction-BH76]
# Key 36 is not in dict_check[reaction-BH76]
# Key 37 is not in dict_check[reaction-BH76]
# Key 38 is not in dict_check[reaction-BH76]
# Key 39 is not in dict_check[reaction-BH76]
# Key 40 is not in dict_check[reaction-BH76]
# Key 41 is not in dict_check[reaction-BH76]
# Key 42 is not in dict_check[reaction-BH76]
# Key 43 is not in dict_check[reaction-BH76]
# Key 44 is not in dict_check[reaction-BH76]
# Key 45 is not in dict_check[reaction-BH76]
# Key 46 is not in dict_check[reaction-BH76]
# Key 47 is not in dict_check[reaction-BH76]
# Key 48 is not in dict_check[reaction-BH76]
# Key 49 is not in dict_check[reaction-BH76]
# Key 50 is not in dict_check[reaction-BH76]
# Key 51 is not in dict_check[reaction-BH76]
# Key 52 is not in dict_check[reaction-BH76]
# Key 53 is not in dict_check[reaction-BH76]
# Key 54 is not in dict_check[reaction-BH76]
# Key 55 is not in dict_check[reaction-BH76]
# Key 56 is not in dict_check[reaction-BH76]
# Key 57 is not in dict_check[reaction-BH76]
# Key 58 is not in dict_check[reaction-BH76]
# Key 59 is not in dict_check[reaction-BH76]
# Key 60 is not in dict_check[reaction-BH76]
# Key 61 is not in dict_check[reaction-BH76]
# Key 62 is not in dict_check[reaction-BH76]
# Key 63 is not in dict_check[reaction-BH76]
# Key 64 is not in dict_check[reaction-BH76]
# Key 65 is not in dict_check[reaction-BH76]
# Key 66 is not in dict_check[reaction-BH76]
# Key 67 is not in dict_check[reaction-BH76]
# Key 68 is not in dict_check[reaction-BH76]
# Key 69 is not in dict_check[reaction-BH76]
# Key 70 is not in dict_check[reaction-BH76]
# Key 71 is not in dict_check[reaction-BH76]
# Key 72 is not in dict_check[reaction-BH76]
# Key 73 is not in dict_check[reaction-BH76]
# Key 74 is not in dict_check[reaction-BH76]
# Key 75 is not in dict_check[reaction-BH76]
# Key 0 is not in dict_check[reaction-ICONF]
# Key 1 is not in dict_check[reaction-ICONF]
# Key 2 is not in dict_check[reaction-ICONF]
# Key 3 is not in dict_check[reaction-ICONF]
# Key 4 is not in dict_check[reaction-ICONF]
# Key 5 is not in dict_check[reaction-ICONF]
# Key 6 is not in dict_check[reaction-ICONF]
# Key 7 is not in dict_check[reaction-ICONF]
# Key 8 is not in dict_check[reaction-ICONF]
# Key 9 is not in dict_check[reaction-ICONF]
# Key 10 is not in dict_check[reaction-ICONF]
# Key 11 is not in dict_check[reaction-ICONF]
# Key 12 is not in dict_check[reaction-ICONF]
# Key 13 is not in dict_check[reaction-ICONF]
# Key 14 is not in dict_check[reaction-ICONF]
# Key 15 is not in dict_check[reaction-ICONF]
# Key 16 is not in dict_check[reaction-ICONF]
# Key 0 is not in dict_check[reaction-MB16_43]
# Key 1 is not in dict_check[reaction-MB16_43]
# Key 2 is not in dict_check[reaction-MB16_43]
# Key 3 is not in dict_check[reaction-MB16_43]
# Key 4 is not in dict_check[reaction-MB16_43]
# Key 5 is not in dict_check[reaction-MB16_43]
# Key 6 is not in dict_check[reaction-MB16_43]
# Key 7 is not in dict_check[reaction-MB16_43]
# Key 8 is not in dict_check[reaction-MB16_43]
# Key 9 is not in dict_check[reaction-MB16_43]
# Key 10 is not in dict_check[reaction-MB16_43]
# Key 11 is not in dict_check[reaction-MB16_43]
# Key 12 is not in dict_check[reaction-MB16_43]
# Key 13 is not in dict_check[reaction-MB16_43]
# Key 14 is not in dict_check[reaction-MB16_43]
# Key 15 is not in dict_check[reaction-MB16_43]
# Key 16 is not in dict_check[reaction-MB16_43]
# Key 17 is not in dict_check[reaction-MB16_43]
# Key 18 is not in dict_check[reaction-MB16_43]
# Key 19 is not in dict_check[reaction-MB16_43]
# Key 20 is not in dict_check[reaction-MB16_43]
# Key 21 is not in dict_check[reaction-MB16_43]
# Key 22 is not in dict_check[reaction-MB16_43]
# Key 23 is not in dict_check[reaction-MB16_43]
# Key 24 is not in dict_check[reaction-MB16_43]
# Key 25 is not in dict_check[reaction-MB16_43]
# Key 26 is not in dict_check[reaction-MB16_43]
# Key 27 is not in dict_check[reaction-MB16_43]
# Key 28 is not in dict_check[reaction-MB16_43]
# Key 29 is not in dict_check[reaction-MB16_43]
# Key 30 is not in dict_check[reaction-MB16_43]
# Key 31 is not in dict_check[reaction-MB16_43]
# Key 32 is not in dict_check[reaction-MB16_43]
# Key 33 is not in dict_check[reaction-MB16_43]
# Key 34 is not in dict_check[reaction-MB16_43]
# Key 35 is not in dict_check[reaction-MB16_43]
# Key 36 is not in dict_check[reaction-MB16_43]
# Key 37 is not in dict_check[reaction-MB16_43]
# Key 38 is not in dict_check[reaction-MB16_43]
# Key 39 is not in dict_check[reaction-MB16_43]
# Key 40 is not in dict_check[reaction-MB16_43]
# Key 41 is not in dict_check[reaction-MB16_43]
# Key 42 is not in dict_check[reaction-MB16_43]
# Key 0 is not in dict_check[reaction-RG18]
# Key 1 is not in dict_check[reaction-RG18]
# Key 2 is not in dict_check[reaction-RG18]
# Key 3 is not in dict_check[reaction-RG18]
# Key 4 is not in dict_check[reaction-RG18]
# Key 5 is not in dict_check[reaction-RG18]
# Key 6 is not in dict_check[reaction-RG18]
# Key 7 is not in dict_check[reaction-RG18]
# Key 8 is not in dict_check[reaction-RG18]
# Key 9 is not in dict_check[reaction-RG18]
# Key 10 is not in dict_check[reaction-RG18]
# Key 11 is not in dict_check[reaction-RG18]
# Key 12 is not in dict_check[reaction-RG18]
# Key 13 is not in dict_check[reaction-RG18]
# Key 14 is not in dict_check[reaction-RG18]
# Key 15 is not in dict_check[reaction-RG18]
# Key 16 is not in dict_check[reaction-RG18]
# Key 17 is not in dict_check[reaction-RG18]
# Key 0 is not in dict_check[reaction-NBPRC]
# Key 1 is not in dict_check[reaction-NBPRC]
# Key 2 is not in dict_check[reaction-NBPRC]
# Key 3 is not in dict_check[reaction-NBPRC]
# Key 4 is not in dict_check[reaction-NBPRC]
# Key 5 is not in dict_check[reaction-NBPRC]
# Key 6 is not in dict_check[reaction-NBPRC]
# Key 7 is not in dict_check[reaction-NBPRC]
# Key 8 is not in dict_check[reaction-NBPRC]
# Key 9 is not in dict_check[reaction-NBPRC]
# Key 10 is not in dict_check[reaction-NBPRC]
# Key 11 is not in dict_check[reaction-NBPRC]
# Key 0 is not in dict_check[reaction-BUT14DIOL]
# Key 1 is not in dict_check[reaction-BUT14DIOL]
# Key 2 is not in dict_check[reaction-BUT14DIOL]
# Key 3 is not in dict_check[reaction-BUT14DIOL]
# Key 4 is not in dict_check[reaction-BUT14DIOL]
# Key 5 is not in dict_check[reaction-BUT14DIOL]
# Key 6 is not in dict_check[reaction-BUT14DIOL]
# Key 7 is not in dict_check[reaction-BUT14DIOL]
# Key 8 is not in dict_check[reaction-BUT14DIOL]
# Key 9 is not in dict_check[reaction-BUT14DIOL]
# Key 10 is not in dict_check[reaction-BUT14DIOL]
# Key 11 is not in dict_check[reaction-BUT14DIOL]
# Key 12 is not in dict_check[reaction-BUT14DIOL]
# Key 13 is not in dict_check[reaction-BUT14DIOL]
# Key 14 is not in dict_check[reaction-BUT14DIOL]
# Key 15 is not in dict_check[reaction-BUT14DIOL]
# Key 16 is not in dict_check[reaction-BUT14DIOL]
# Key 17 is not in dict_check[reaction-BUT14DIOL]
# Key 18 is not in dict_check[reaction-BUT14DIOL]
# Key 19 is not in dict_check[reaction-BUT14DIOL]
# Key 20 is not in dict_check[reaction-BUT14DIOL]
# Key 21 is not in dict_check[reaction-BUT14DIOL]
# Key 22 is not in dict_check[reaction-BUT14DIOL]
# Key 23 is not in dict_check[reaction-BUT14DIOL]
# Key 24 is not in dict_check[reaction-BUT14DIOL]
# Key 25 is not in dict_check[reaction-BUT14DIOL]
# Key 26 is not in dict_check[reaction-BUT14DIOL]
# Key 27 is not in dict_check[reaction-BUT14DIOL]
# Key 28 is not in dict_check[reaction-BUT14DIOL]
# Key 29 is not in dict_check[reaction-BUT14DIOL]
# Key 30 is not in dict_check[reaction-BUT14DIOL]
# Key 31 is not in dict_check[reaction-BUT14DIOL]
# Key 32 is not in dict_check[reaction-BUT14DIOL]
# Key 33 is not in dict_check[reaction-BUT14DIOL]
# Key 34 is not in dict_check[reaction-BUT14DIOL]
# Key 35 is not in dict_check[reaction-BUT14DIOL]
# Key 36 is not in dict_check[reaction-BUT14DIOL]
# Key 37 is not in dict_check[reaction-BUT14DIOL]
# Key 38 is not in dict_check[reaction-BUT14DIOL]
# Key 39 is not in dict_check[reaction-BUT14DIOL]
# Key 40 is not in dict_check[reaction-BUT14DIOL]
# Key 41 is not in dict_check[reaction-BUT14DIOL]
# Key 42 is not in dict_check[reaction-BUT14DIOL]
# Key 43 is not in dict_check[reaction-BUT14DIOL]
# Key 44 is not in dict_check[reaction-BUT14DIOL]
# Key 45 is not in dict_check[reaction-BUT14DIOL]
# Key 46 is not in dict_check[reaction-BUT14DIOL]
# Key 47 is not in dict_check[reaction-BUT14DIOL]
# Key 48 is not in dict_check[reaction-BUT14DIOL]
# Key 49 is not in dict_check[reaction-BUT14DIOL]
# Key 50 is not in dict_check[reaction-BUT14DIOL]
# Key 51 is not in dict_check[reaction-BUT14DIOL]
# Key 52 is not in dict_check[reaction-BUT14DIOL]
# Key 53 is not in dict_check[reaction-BUT14DIOL]
# Key 54 is not in dict_check[reaction-BUT14DIOL]
# Key 55 is not in dict_check[reaction-BUT14DIOL]
# Key 56 is not in dict_check[reaction-BUT14DIOL]
# Key 57 is not in dict_check[reaction-BUT14DIOL]
# Key 58 is not in dict_check[reaction-BUT14DIOL]
# Key 59 is not in dict_check[reaction-BUT14DIOL]
# Key 60 is not in dict_check[reaction-BUT14DIOL]
# Key 61 is not in dict_check[reaction-BUT14DIOL]
# Key 62 is not in dict_check[reaction-BUT14DIOL]
# Key 63 is not in dict_check[reaction-BUT14DIOL]
# Key 0 is not in dict_check[reaction-HEAVY28]
# Key 1 is not in dict_check[reaction-HEAVY28]
# Key 2 is not in dict_check[reaction-HEAVY28]
# Key 3 is not in dict_check[reaction-HEAVY28]
# Key 4 is not in dict_check[reaction-HEAVY28]
# Key 5 is not in dict_check[reaction-HEAVY28]
# Key 6 is not in dict_check[reaction-HEAVY28]
# Key 7 is not in dict_check[reaction-HEAVY28]
# Key 8 is not in dict_check[reaction-HEAVY28]
# Key 9 is not in dict_check[reaction-HEAVY28]
# Key 10 is not in dict_check[reaction-HEAVY28]
# Key 11 is not in dict_check[reaction-HEAVY28]
# Key 12 is not in dict_check[reaction-HEAVY28]
# Key 13 is not in dict_check[reaction-HEAVY28]
# Key 14 is not in dict_check[reaction-HEAVY28]
# Key 15 is not in dict_check[reaction-HEAVY28]
# Key 16 is not in dict_check[reaction-HEAVY28]
# Key 17 is not in dict_check[reaction-HEAVY28]
# Key 18 is not in dict_check[reaction-HEAVY28]
# Key 19 is not in dict_check[reaction-HEAVY28]
# Key 20 is not in dict_check[reaction-HEAVY28]
# Key 21 is not in dict_check[reaction-HEAVY28]
# Key 22 is not in dict_check[reaction-HEAVY28]
# Key 23 is not in dict_check[reaction-HEAVY28]
# Key 24 is not in dict_check[reaction-HEAVY28]
# Key 25 is not in dict_check[reaction-HEAVY28]
# Key 26 is not in dict_check[reaction-HEAVY28]
# Key 27 is not in dict_check[reaction-HEAVY28]
# Key 0 is not in dict_check[reaction-SCONF]
# Key 1 is not in dict_check[reaction-SCONF]
# Key 2 is not in dict_check[reaction-SCONF]
# Key 3 is not in dict_check[reaction-SCONF]
# Key 4 is not in dict_check[reaction-SCONF]
# Key 5 is not in dict_check[reaction-SCONF]
# Key 6 is not in dict_check[reaction-SCONF]
# Key 7 is not in dict_check[reaction-SCONF]
# Key 8 is not in dict_check[reaction-SCONF]
# Key 9 is not in dict_check[reaction-SCONF]
# Key 10 is not in dict_check[reaction-SCONF]
# Key 11 is not in dict_check[reaction-SCONF]
# Key 12 is not in dict_check[reaction-SCONF]
# Key 13 is not in dict_check[reaction-SCONF]
# Key 14 is not in dict_check[reaction-SCONF]
# Key 15 is not in dict_check[reaction-SCONF]
# Key 16 is not in dict_check[reaction-SCONF]
# Key 0 is not in dict_check[reaction-CARBHB12]
# Key 1 is not in dict_check[reaction-CARBHB12]
# Key 2 is not in dict_check[reaction-CARBHB12]
# Key 3 is not in dict_check[reaction-CARBHB12]
# Key 4 is not in dict_check[reaction-CARBHB12]
# Key 5 is not in dict_check[reaction-CARBHB12]
# Key 6 is not in dict_check[reaction-CARBHB12]
# Key 7 is not in dict_check[reaction-CARBHB12]
# Key 8 is not in dict_check[reaction-CARBHB12]
# Key 9 is not in dict_check[reaction-CARBHB12]
# Key 10 is not in dict_check[reaction-CARBHB12]
# Key 11 is not in dict_check[reaction-CARBHB12]
# Key 0 is not in dict_check[reaction-MCONF]
# Key 1 is not in dict_check[reaction-MCONF]
# Key 2 is not in dict_check[reaction-MCONF]
# Key 3 is not in dict_check[reaction-MCONF]
# Key 4 is not in dict_check[reaction-MCONF]
# Key 5 is not in dict_check[reaction-MCONF]
# Key 6 is not in dict_check[reaction-MCONF]
# Key 7 is not in dict_check[reaction-MCONF]
# Key 8 is not in dict_check[reaction-MCONF]
# Key 9 is not in dict_check[reaction-MCONF]
# Key 10 is not in dict_check[reaction-MCONF]
# Key 11 is not in dict_check[reaction-MCONF]
# Key 12 is not in dict_check[reaction-MCONF]
# Key 13 is not in dict_check[reaction-MCONF]
# Key 14 is not in dict_check[reaction-MCONF]
# Key 15 is not in dict_check[reaction-MCONF]
# Key 16 is not in dict_check[reaction-MCONF]
# Key 17 is not in dict_check[reaction-MCONF]
# Key 18 is not in dict_check[reaction-MCONF]
# Key 19 is not in dict_check[reaction-MCONF]
# Key 20 is not in dict_check[reaction-MCONF]
# Key 21 is not in dict_check[reaction-MCONF]
# Key 22 is not in dict_check[reaction-MCONF]
# Key 23 is not in dict_check[reaction-MCONF]
# Key 24 is not in dict_check[reaction-MCONF]
# Key 25 is not in dict_check[reaction-MCONF]
# Key 26 is not in dict_check[reaction-MCONF]
# Key 27 is not in dict_check[reaction-MCONF]
# Key 28 is not in dict_check[reaction-MCONF]
# Key 29 is not in dict_check[reaction-MCONF]
# Key 30 is not in dict_check[reaction-MCONF]
# Key 31 is not in dict_check[reaction-MCONF]
# Key 32 is not in dict_check[reaction-MCONF]
# Key 33 is not in dict_check[reaction-MCONF]
# Key 34 is not in dict_check[reaction-MCONF]
# Key 35 is not in dict_check[reaction-MCONF]
# Key 36 is not in dict_check[reaction-MCONF]
# Key 37 is not in dict_check[reaction-MCONF]
# Key 38 is not in dict_check[reaction-MCONF]
# Key 39 is not in dict_check[reaction-MCONF]
# Key 40 is not in dict_check[reaction-MCONF]
# Key 41 is not in dict_check[reaction-MCONF]
# Key 42 is not in dict_check[reaction-MCONF]
# Key 43 is not in dict_check[reaction-MCONF]
# Key 44 is not in dict_check[reaction-MCONF]
# Key 45 is not in dict_check[reaction-MCONF]
# Key 46 is not in dict_check[reaction-MCONF]
# Key 47 is not in dict_check[reaction-MCONF]
# Key 48 is not in dict_check[reaction-MCONF]
# Key 49 is not in dict_check[reaction-MCONF]
# Key 50 is not in dict_check[reaction-MCONF]
# Key ADDON_Se is not in dict_new
# Key ADDON_Ge is not in dict_new
# Key ADDON_As is not in dict_new
# Key ADDON_Sb is not in dict_new
# Key ADDON_Te is not in dict_new
# Key ADDON_I is not in dict_new
# Key ADDON_Bi is not in dict_new
# Key ADDON_Pb is not in dict_new

# %%
# # for clean up
# import json
# import re
# import sys

# import numpy as np


# sys.path.append("../cadft")
# from cc2cc.utils.basis import gen_basis
# from cc2cc.utils.rotate import rotate

# dict_new = {"molecule": [], "spin": {}, "charge": {}}

# with open(f"gmtkn-{BASIS}.json", "r") as f:
#     dict_ = json.load(f)

# for key in dict_:
#     if re.match(r"molecule[0-9]+", key):
#         dict_new[key] = []
#         print(f"Processing {dict_[key]}")
#         for molecule in dict_[key]:
#             molecule_list = np.array(dict_[molecule], dtype=object)
#             molecule_list = molecule_list[np.argsort(molecule_list[:, 0])]
#             rotate(molecule_list)

#             add_flag = True

#             duplicate_flag = False
#             for molecule_new in dict_new[key]:
#                 molecule_new_list = np.array(dict_[molecule_new], dtype=object)
#                 molecule_new_list = molecule_new_list[
#                     np.argsort(molecule_new_list[:, 0])
#                 ]
#                 rotate(molecule_new_list)

#                 if len(molecule_new_list) != len(molecule_list):
#                     continue

#                 for i_atom in range(len(molecule_list)):
#                     if (
#                         molecule_new_list[i_atom][0] == molecule_list[i_atom][0]
#                         and (
#                             dict_["charge"][molecule] == dict_["charge"][molecule_new]
#                             and dict_["spin"][molecule] == dict_["spin"][molecule_new]
#                         )
#                         and np.linalg.norm(
#                             molecule_new_list[i_atom][1:] - molecule_list[i_atom][1:]
#                         )
#                         < 1e-7
#                     ):
#                         duplicate_flag = True
#                     else:
#                         duplicate_flag = False
#                         break

#                 if duplicate_flag:
#                     add_flag = False
#                     break

#             if add_flag:
#                 dict_new[key].append(molecule)
#                 dict_new[molecule] = dict_[molecule]
#                 dict_new["molecule"].append(molecule)
#                 dict_new["charge"][molecule] = dict_["charge"][molecule]
#                 dict_new["spin"][molecule] = dict_["spin"][molecule]
#             else:
#                 print(
#                     f"spin and charge: [{dict_['spin'][molecule]}, {dict_['charge'][molecule]}] with [{dict_['spin'][molecule_new]}, {dict_['charge'][molecule_new]}]"
#                 )
#                 print(
#                     f"Comparing atom and coordinates: \n {molecule_new_list} \n and \n {molecule_list}"
#                 )
#                 print(f"Duplicate found: {molecule} and {molecule_new}\n")
#                 dict_new[molecule] = molecule_new

#         print(len(dict_[key]), len(dict_new[key]))
#         print(f"remove duplicates: {[_ for _ in dict_[key] if _ not in dict_new[key]]}")
#         print()
#     elif re.match(r"reaction-.*", key):
#         dict_new[key] = dict_[key]
#         print(f"Reaction '{key}'.")
#     elif re.match(r"molecule_.*", key):
#         dict_new[key] = dict_[key]
#         print(f"molecule key '{key}' processed.")

# with open(f"filtered_gmtkn-{BASIS}.json", "w") as f:
#     json.dump(dict_new, f)

# print(f"Filtered data has been saved to filtered_gmtkn-{BASIS}.json")
# print("DONE")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 10
#       6 import numpy as np
#       9 sys.path.append("../cadft")
# ---> 10 from cc2cc.utils.basis import gen_basis
#      11 from cc2cc.utils.rotate import rotate
#      13 dict_new = {"molecule": [], "spin": {}, "charge": {}}
#
# ModuleNotFoundError: No module named 'cc2cc.utils.basis'
