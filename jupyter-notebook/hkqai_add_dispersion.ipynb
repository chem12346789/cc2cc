# %%
from pathlib import Path

import pandas as pd

# !cp ~/workspace/cc2cc_test5/validate/*.csv ~/workspace/cc2cc_test5/validate_hkqai
name_mol_list = [
    "molecule_W4_11",
    "molecule_G21EA",
    "molecule_G21IP",
    "molecule_DIPCS10",
    "molecule_PA26",
    "molecule_SIE4x4",
    "molecule_ALKBDE10",
    "molecule_YBDE18",
    "molecule_AL2X6",
    "molecule_HEAVYSB11",
    "molecule_NBPRC",
    "molecule_ALK8",
    "molecule_RC21",
    "molecule_G2RC",
    "molecule_BH76",
    "molecule_FH51",
    "molecule_TAUT15",
    "molecule_DC13",
    "molecule_MB16_43",
    "molecule_DARC",
    "molecule_RSE43",
    "molecule_BSR36",
    "molecule_CDIE20",
    "molecule_ISO34",
    "molecule_ISOL24",
    "molecule_C60ISO",
    "molecule_PArel",
    "molecule_BHPERI",
    "molecule_BHDIV10",
    "molecule_INV24",
    "molecule_BHROT27",
    "molecule_PX13",
    "molecule_WCPT18",
    "molecule_RG18",
    "molecule_ADIM6",
    "molecule_S22",
    "molecule_S66",
    "molecule_HEAVY28",
    "molecule_WATER27",
    "molecule_CARBHB12",
    "molecule_PNICO23",
    "molecule_HAL59",
    "molecule_AHB21",
    "molecule_CHB6",
    "molecule_IL16",
    "molecule_IDISP",
    "molecule_ICONF",
    "molecule_ACONF",
    "molecule_Amino20x4",
    "molecule_PCONF21",
    "molecule_MCONF",
    "molecule_SCONF",
    "molecule_UPU23",
    "molecule_BUT14DIOL",
]

if_start_file = {}

for i, name_mol in enumerate(name_mol_list):
    data_path_list = sorted(
        list(Path("../validate_hkqai").glob(f"*{name_mol}.csv")),
        key=lambda p: p.stat().st_ctime,
    )

    for data_path in data_path_list:
        summary_data_path = data_path.stem.split("_" + name_mol)[0] + ".csv"

        with open(data_path, "r") as f:
            data = pd.read_csv(f)

        if if_start_file.get(summary_data_path, True):
            with open(Path("../validate_hkqai") / summary_data_path, "w") as f2:
                data.to_csv(f2, index=False)
            if_start_file[summary_data_path] = False
        else:
            with open(Path("../validate_hkqai") / summary_data_path, "a") as f2:
                data.to_csv(f2, index=False, header=False)

for i, name_mol in enumerate(name_mol_list):
    for data_path in list(Path("../validate_hkqai").glob(f"*{name_mol}.csv")):
        data_path.unlink()

# for data_path in list(Path("../validate_hkqai").glob(f"*test*.csv")):
#     data_path.unlink()

# %%
# import json
# from pathlib import Path
# from datetime import datetime
# import os 

# import pandas as pd
# import numpy as np

# MAIN_PATH = os.environ.get("DFT2CC_MAIN_PATH")
# if MAIN_PATH is None:
#     MAIN_PATH = Path("../")
# else:
#     MAIN_PATH = Path(MAIN_PATH)

# DATA_TEST_DIR = os.environ.get("DFT2CC_DATA_TEST_DIR")
# if DATA_TEST_DIR is None:
#     DATA_TEST_PATH = MAIN_PATH / "data" / "test"
# else:
#     DATA_TEST_PATH = MAIN_PATH / "data" / DATA_TEST_DIR

# DATA_TEST_NO_GRAD_DIR = os.environ.get("DFT2CC_DATA_TEST_NO_GRAD_DIR")
# if DATA_TEST_NO_GRAD_DIR is None:
#     DATA_TEST_NO_GRAD_PATH = MAIN_PATH / "data" / "test_no_grad"
# else:
#     DATA_TEST_NO_GRAD_PATH = MAIN_PATH / "data" / DATA_TEST_NO_GRAD_DIR

# verbose = 1
# data_set = "gmtkn-cc-pVDZ"

# data_path_list = sorted(
#     list(Path("../validate_hkqai").glob(f"*gmtkn*.csv")),
#     key=lambda p: p.stat().st_ctime,
# )

# for data_path in data_path_list:
#     data = pd.read_csv(data_path)
#     for name in data["name"]:
#         if not (DATA_TEST_NO_GRAD_PATH / f"{name}_cc.npz").exists():
#             if verbose:
#                 print(f"Skipping {name} as data file does not exist.")
#             continue
#         # load the data
#         data_frame = np.load(DATA_TEST_NO_GRAD_PATH / f"{name}_cc.npz")
#         if "e_dft_d3bj" not in data_frame:
#             if verbose:
#                 print(f"Skipping {name} as e_dft_d3bj is missing.")
#             data.loc[data["name"] == name, "delta_d3bj"] = 0
#         else:
#             data.loc[data["name"] == name, "delta_d3bj"] = (
#                 data_frame["e_dft_d3bj"].item() - data_frame["e_dft"].item()
#             )
#         if "e_dft_d3zero" not in data_frame:
#             if verbose:
#                 print(f"Skipping {name} as e_dft_d3zero is missing.")
#             data.loc[data["name"] == name, "delta_d3zero"] = 0
#         else:
#             data.loc[data["name"] == name, "delta_d3zero"] = (
#                 data_frame["e_dft_d3zero"].item() - data_frame["e_dft"].item()
#             )
#     # save the processed data
#     data.to_csv(data_path, index=False)
# Out:
# Skipping W4_11-al_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-b_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-be_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cl_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-f_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-h_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-o_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-p_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-s_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-si_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-alcl_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-alf_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-alh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-b2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-be2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-bf_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-bh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-bn_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-bn3pi_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cf_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cl2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-clf_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-clo_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cn_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-co_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cs_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-f2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-h2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hcl_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hf_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hs_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-n2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-nh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-no_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-o2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-of_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-oh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-p2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-s2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-sif_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-sih_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-sio_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-so_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-becl2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-bef2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cch_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ccl2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cf2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch2-sing_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch2-trip_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cl2o_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-clcn_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cloo_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-co2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cs2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-f2o_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-fo2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-h2o_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-h2s_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hcn_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hco_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hnc_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hno_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hocl_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hof_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hoo_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-n2h_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-n2o_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-nh2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-no2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-o3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-oclo_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ocs_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-s2o_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-s3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-so2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ssh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-alcl3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-alf3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-alh3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-bf3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-bh3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-bhf2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c-hcoh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c-hono_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c-hooo_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c-n2h2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c2h2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch2c_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-f2co_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-fccf_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-foof_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-h2cn_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-h2co_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hccf_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hcnh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hcno_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hcof_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hnco_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hnnn_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hocn_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-honc_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-hooh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-nccn_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-nh2cl_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-nh3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-p4_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ph3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-s4-c2v_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-so3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-t-hcoh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-t-hono_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-t-hooo_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-t-n2h2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-cf4_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch2ch_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch2f2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch2nh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch3f_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch4_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-dioxirane_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-formic_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ketene_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-oxirene_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-sif4_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-sih3f_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-sih4_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c2h3f_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c2h4_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch2nh2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch3nh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-glyoxal_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-methanol_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-n2h4_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-acetaldehyde_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-allene_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ch3nh2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-oxirane_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-propyne_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-acetic_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-b2h6_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c2h5f_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-c2h6_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-si2h6_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-ethanol_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-propene_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping W4_11-propane_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_c_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_c-_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_cl_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_cl-_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_f_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_f-_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_o_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_o-_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_p_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_p-_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_s_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_s-_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_si_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_si-_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_11_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_11n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_13_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_13n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_14_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_14n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_17_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_17n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_19_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_19n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_20_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_20n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_21_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_21n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_22_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_22n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_23_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_23n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_24_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_24n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_25_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_25n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_8_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_8n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_12_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_12n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_15_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_15n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_18_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_18n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_9_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_9n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_10_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_10n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_16_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21EA-EA_16n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-al_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-al+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-b_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-b+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-be_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-be+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-c_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-c+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-cl_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-cl+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-f_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-f+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-h_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-li_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-li+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-mg_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-mg+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-n_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-n+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-na_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-na+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-o_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-o+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-p_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-p+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-s_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-s+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-si_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-si+_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-12_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-137_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-14_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-22_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-30_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-34_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-37_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-43_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-44_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-45_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-48_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-51_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_61_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_63_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_65_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_68_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_70_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_73_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_74_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_75_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_76_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP_77_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping G21IP-IP
_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hcl_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hf_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-n2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-oh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-oh-_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-H2O_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-H2S_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-N2H_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-NH2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-PH2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT01_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT06_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT10_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT13_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT14_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT17_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hclhts_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hcn_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hcnts_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hco_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hcots_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hf2ts_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hfhts_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hn2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hn2ts_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-hnc_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-n2o_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-N2H2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-NH3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-PH3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT02_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT16_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-ch3_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-n2ohts_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-CH2OH_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-CH4_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT12_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT15_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-ch3cl_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-ch3f_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT03_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT07_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT08_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-RKT11_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-c2h4_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-ch3fclts_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-ch3oh_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-clch3clcomp_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-clch3clts_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-fch3clcomp1_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-fch3clcomp2_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-fch3clts_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# Skipping BH76-fch3fcomp_cc-pVDZ_0_1_0.0000_default as data file does not exist.
# ...
# Skipping Amino20x4-GLU_xar_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-GLU_xav_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-GLU_xbi_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-VAL_xad_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-VAL_xaf_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-VAL_xah_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-VAL_xaj_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-VAL_xak_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-GLN_xai_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-GLN_xal_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-GLN_xan_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-GLN_xap_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-GLN_xat_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-HIS_xah_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-HIS_xam_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-HIS_xaq_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-HIS_xau_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-HIS_xav_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-MET_xag_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-MET_xav_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-MET_xbf_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-MET_xbm_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-MET_xbo_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ILE_xae_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ILE_xag_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ILE_xaj_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ILE_xak_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ILE_xaq_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LEU_xad_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LEU_xae_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LEU_xap_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LEU_xaq_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LEU_xbb_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-PHE_xab_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-PHE_xal_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-PHE_xan_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-PHE_xar_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-PHE_xaw_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LYS_xan_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LYS_xao_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LYS_xap_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LYS_xas_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-LYS_xat_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TYR_xab_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TYR_xag_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TYR_xah_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TYR_xan_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TYR_xar_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ARG_xak_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ARG_xbv_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ARG_xbx_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ARG_xby_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-ARG_xci_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TRP_xac_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TRP_xaf_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TRP_xag_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TRP_xah_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping Amino20x4-TRP_xao_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-114_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-215_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-224_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-300_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-357_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-366_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-412_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-444_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-470_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-691_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-99_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-GLY_aL_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-GLY_aR_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-GLY_ab_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-GLY_b_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-GLY_pII_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-SER_aL_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-SER_aR_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-SER_ab_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping PCONF21-SER_b_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-1_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-10_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-11_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-12_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-13_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-14_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-15_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-16_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-17_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-18_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-19_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-2_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-20_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-21_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-22_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-23_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-24_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-25_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-26_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-27_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-28_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-29_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-3_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-30_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-31_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-32_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-33_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-34_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-35_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-36_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-37_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-38_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-39_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-4_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-40_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-41_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-42_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-43_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-44_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-45_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-46_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-47_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-48_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-49_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-5_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-50_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-51_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-52_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-6_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-7_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-8_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping MCONF-9_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-G1_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-G2_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-G3_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-G4_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C1_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C10_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C11_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C12_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C13_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C14_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C15_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C2_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C3_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C4_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C5_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C6_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C7_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C8_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping SCONF-C9_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping UPU23-0a_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping UPU23-0b_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping UPU23-1a_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping UPU23-1b_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B1_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B10_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B11_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B12_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B13_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B14_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B15_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B16_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B17_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B18_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B19_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B2_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B20_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B21_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B22_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B23_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B24_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B25_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B26_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B27_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B28_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B29_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B3_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B30_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B31_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B32_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B33_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B34_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B35_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B36_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B37_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B38_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B39_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B4_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B40_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B41_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B42_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B43_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B44_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B45_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B46_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B47_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B48_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B49_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B5_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B50_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B51_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B52_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B53_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B54_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B55_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B56_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B57_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B58_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B59_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B6_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B60_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B61_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B62_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B63_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B64_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B65_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B7_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B8_def2-TZVPD_0_1_0.0000 as data file does not exist.
# Skipping BUT14DIOL-B9_def2-TZVPD_0_1_0.0000 as data file does not exist.
