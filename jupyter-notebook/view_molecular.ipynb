# %%
import py3Dmol

from cc2cc.utils import gen_mole

mol = gen_mole("MB16_43-36", 0, 1, 0, "cc-pVDZ", True, "gmtkn")

xyz = mol.tostring(format="xyz")

xyzview = py3Dmol.view()
xyzview.addModel(xyz, "xyz")
xyzview.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
xyzview.setStyle(
    {
        "stick": {},
        "sphere": {"scale": 0.3},
        "label": "atom",
    }
)
xyzview.setHoverable(
    {},
    True,
    """function(atom,viewer,event,container) {
        if(!atom.label) {
        atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});
        }}""",
    """function(atom,viewer) {
        if(atom.label) {
        viewer.removeLabel(atom.label);
        delete atom.label;
        }
    }""",
    viewer=(0, 0),
)
xyzview.zoomTo()
xyzview.show()
# Out:
# LEVEL: 3
# PERIOD: 2
# CUBE_SIZE: 3
# CUBE_MIDDLE: 1
# CUBE_LEN: 0.1
# TEST: False
# MAIN_PATH: /home/dhem/workspace/2025.1
# DATA_PATH: /home/dhem/workspace/2025.1/data/grids_dft
# DATA_TEST_PATH: /home/dhem/workspace/2025.1/data/test
# DATA_SCF_PATH: /home/dhem/workspace/2025.1/data/grids_scf
# CHECKPOINTS_PATH: /home/dhem/workspace/2025.1/checkpoints
# GENERATE_DATA: False
# <div id="3dmolviewer_17497128916141086"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17497128916141086" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17497128916141086 = null;
# var warn = document.getElementById("3dmolwarning_17497128916141086");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17497128916141086 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17497128916141086"),{backgroundColor:"white"});
# viewer_17497128916141086.zoomTo();
# 	viewer_17497128916141086.addModel("16\nXYZ from PySCF\nN           0.91032        1.03080       -3.04192\nH          -0.44739       -1.46087        1.72254\nH           0.22488       -0.59870        3.14821\nC           0.38678       -0.86002        2.09683\nH           1.10208        1.31316       -2.07266\nP           0.49305        0.64634        1.12367\nH           1.31853       -1.42311        1.99327\nH           1.15676        1.60243       -3.84839\nLi         -0.44029       -0.73332       -1.50370\nCl         -1.76334       -2.20950       -0.56412\nO           0.56223        0.46116       -0.37782\nH          -0.53828        1.49172        1.55544\nH          -2.32872       -0.71362        0.44007\nO           0.12567        0.02597       -3.22615\nH           1.64874        1.30371        1.59976\nF          -2.41104        0.12385        0.95498","xyz");
# 	viewer_17497128916141086.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17497128916141086.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17497128916141086.setHoverable({},true,"function(atom,viewer,event,container) {\n        if(!atom.label) {\n        atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n        }}","function(atom,viewer) {\n        if(atom.label) {\n        viewer.removeLabel(atom.label);\n        delete atom.label;\n        }\n    }");
# 	viewer_17497128916141086.zoomTo();
# viewer_17497128916141086.render();
# });
# </script>
