# %%
import py3Dmol

from cc2cc.utils import gen_mole

name_mol_list = [
    "Amino20x4-MET_xag",
    "Amino20x4-MET_xav",
    "Amino20x4-MET_xbf",
    "Amino20x4-MET_xbm",
    "Amino20x4-MET_xbo",
]

for name_mol in name_mol_list:
    # Generate the molecule with the specified parameters
    # The parameters are: 
    #       name, stratch_atom, stratch_orientation, stratch_distance and basis set
    mol = gen_mole(name_mol, 0, 1, 0, "cc-pVDZ", True, "gmtkn")

    xyz = mol.tostring(format="xyz")

    xyzview = py3Dmol.view()
    xyzview.addModel(xyz, "xyz")
    xyzview.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
    xyzview.setStyle(
        {
            "stick": {},
            "sphere": {"scale": 0.3},
            "label": "atom",
        }
    )
    xyzview.setHoverable(
        {},
        True,
        """function(atom,viewer,event,container) {
            if(!atom.label) {
            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});
            }}""",
        """function(atom,viewer) {
            if(atom.label) {
            viewer.removeLabel(atom.label);
            delete atom.label;
            }
        }""",
        viewer=(0, 0),
    )
    xyzview.zoomTo()
    xyzview.show()
# Out:
# <div id="3dmolviewer_17502258158279529"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17502258158279529" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17502258158279529 = null;
# var warn = document.getElementById("3dmolwarning_17502258158279529");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17502258158279529 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17502258158279529"),{backgroundColor:"white"});
# viewer_17502258158279529.zoomTo();
# 	viewer_17502258158279529.addModel("29\nXYZ from PySCF\nN          -0.24119        0.84100        0.12033\nH          -1.07054        0.36894       -0.21962\nC           0.57382        0.14547        1.10591\nH           0.91317        0.90087        1.81907\nC          -0.23904       -0.91153        1.84169\nH          -0.98835       -0.41805        2.46384\nH           0.44703       -1.43293        2.50716\nC          -0.90892       -1.95549        0.94631\nH          -0.26545       -2.19821        0.10311\nH          -1.08608       -2.87017        1.51091\nS          -2.51837       -1.36470        0.32918\nC          -2.83865       -2.68167       -0.86387\nH          -3.79785       -2.47539       -1.33153\nH          -2.88990       -3.64314       -0.35769\nH          -2.06354       -2.70685       -1.62623\nC           1.83504       -0.46795        0.46980\nO           2.05209       -1.67794        0.47546\nN           2.65966        0.45687       -0.06263\nH           2.36112        1.42568       -0.00574\nC          -0.00050        2.11586       -0.25555\nO           0.98902        2.74807        0.12499\nC          -1.02081        2.72377       -1.18338\nH          -1.38094        3.64811       -0.73817\nH          -1.86187        2.06409       -1.38099\nH          -0.53136        2.97907       -2.12067\nC           3.88207        0.09429       -0.74405\nH           4.73172        0.61964       -0.31261\nH           4.02385       -0.97518       -0.62358\nH           3.82659        0.32863       -1.80637","xyz");
# 	viewer_17502258158279529.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17502258158279529.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17502258158279529.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17502258158279529.zoomTo();
# viewer_17502258158279529.render();
# });
# </script>
# <div id="3dmolviewer_17502258159297202"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17502258159297202" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17502258159297202 = null;
# var warn = document.getElementById("3dmolwarning_17502258159297202");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17502258159297202 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17502258159297202"),{backgroundColor:"white"});
# viewer_17502258159297202.zoomTo();
# 	viewer_17502258159297202.addModel("29\nXYZ from PySCF\nN           2.10390        0.13202        0.13399\nH           2.49250        0.96543        0.54777\nC           0.67018        0.10938       -0.00832\nH           0.42605       -0.32628       -0.97769\nC           0.03636       -0.74520        1.10082\nH           0.37536       -0.34961        2.06035\nH           0.43768       -1.75254        0.98888\nC          -1.48571       -0.78463        1.10155\nH          -1.83468       -1.47417        1.87042\nH          -1.90085        0.20224        1.31296\nS          -2.13080       -1.34454       -0.50268\nC          -3.89088       -1.20407       -0.12103\nH          -4.44313       -1.49743       -1.01004\nH          -4.14986       -0.17928        0.13819\nH          -4.15666       -1.86933        0.69751\nC           0.19634        1.55409        0.06966\nO           0.82855        2.39641        0.70474\nN          -0.95445        1.80815       -0.58840\nH          -1.43351        1.02115       -1.00652\nC           2.87424       -0.90154       -0.28801\nO           2.39490       -1.90918       -0.79831\nC           4.35969       -0.72942       -0.08136\nH           4.86004       -0.88269       -1.03408\nH           4.70620       -1.50148        0.60190\nH           4.62630        0.24698        0.31529\nC          -1.59886        3.10254       -0.52686\nH          -0.84721        3.83681       -0.25493\nH          -2.01731        3.35412       -1.49778\nH          -2.39266        3.12536        0.22031","xyz");
# 	viewer_17502258159297202.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17502258159297202.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17502258159297202.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17502258159297202.zoomTo();
# viewer_17502258159297202.render();
# });
# </script>
# <div id="3dmolviewer_17502258160290477"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17502258160290477" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17502258160290477 = null;
# var warn = document.getElementById("3dmolwarning_17502258160290477");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17502258160290477 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17502258160290477"),{backgroundColor:"white"});
# viewer_17502258160290477.zoomTo();
# 	viewer_17502258160290477.addModel("29\nXYZ from PySCF\nN           1.79706        0.55168        0.16459\nH           2.08768        1.45779        0.49858\nC           0.37510        0.33591        0.06613\nH           0.16914       -0.20843       -0.85493\nC          -0.12490       -0.49070        1.25726\nH           0.07716        0.07226        2.17152\nH           0.48540       -1.39310        1.28771\nC          -1.60251       -0.86366        1.22537\nH          -1.81847       -1.57109        2.02642\nH          -2.23304        0.01147        1.38280\nS          -2.18197       -1.56816       -0.34664\nC          -0.95807       -2.88178       -0.57096\nH          -1.24850       -3.42137       -1.46911\nH          -0.98845       -3.56680        0.27416\nH           0.04748       -2.48529       -0.69778\nC          -0.28469        1.70547        0.03004\nO           0.23462        2.67484        0.57991\nN          -1.46902        1.73482       -0.61633\nH          -1.79431        0.86842       -1.02241\nC           2.67650       -0.42218       -0.16660\nO           2.31021       -1.53033       -0.55504\nC           4.13449       -0.05493       -0.04490\nH           4.57353       -0.04821       -1.04031\nH           4.63933       -0.82399        0.53360\nH           4.29167        0.91448        0.42107\nC          -2.28377        2.92854       -0.69102\nH          -2.42188        3.24102       -1.72418\nH          -3.25929        2.76311       -0.23722\nH          -1.76435        3.71225       -0.14870","xyz");
# 	viewer_17502258160290477.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17502258160290477.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17502258160290477.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17502258160290477.zoomTo();
# viewer_17502258160290477.render();
# });
# </script>
# <div id="3dmolviewer_17502258161281683"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17502258161281683" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17502258161281683 = null;
# var warn = document.getElementById("3dmolwarning_17502258161281683");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17502258161281683 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17502258161281683"),{backgroundColor:"white"});
# viewer_17502258161281683.zoomTo();
# 	viewer_17502258161281683.addModel("29\nXYZ from PySCF\nN           1.36870       -1.18086        0.39436\nH           1.09830       -1.64892        1.24288\nC           0.37337       -0.37332       -0.29721\nH           0.61282       -0.43091       -1.36060\nC          -1.01791       -0.91338       -0.02285\nH          -1.25474       -0.72891        1.02513\nH          -1.02992       -1.98980       -0.19610\nC          -2.06030       -0.24542       -0.90834\nH          -1.93897       -0.56529       -1.94379\nH          -1.95661        0.83886       -0.87485\nS          -3.76207       -0.66220       -0.45004\nC          -3.90218        0.38333        1.01782\nH          -4.90663        0.24504        1.41040\nH          -3.75922        1.42886        0.75541\nH          -3.18200        0.10076        1.78094\nC           0.49136        1.08670        0.16562\nO          -0.29022        1.58251        0.97305\nN           1.53313        1.74305       -0.38798\nH           2.20445        1.17659       -0.89333\nC           2.65382       -1.26035       -0.02894\nO           3.06248       -0.63535       -1.00793\nC           3.55146       -2.17810        0.76007\nH           4.42601       -1.61725        1.07951\nH           3.89171       -2.97430        0.10188\nH           3.06409       -2.61535        1.62767\nC           1.88145        3.08052        0.04241\nH           2.42046        3.58579       -0.75364\nH           0.96658        3.62195        0.26260\nH           2.49780        3.07214        0.94185","xyz");
# 	viewer_17502258161281683.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17502258161281683.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17502258161281683.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17502258161281683.zoomTo();
# viewer_17502258161281683.render();
# });
# </script>
# <div id="3dmolviewer_1750225816233232"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_1750225816233232" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_1750225816233232 = null;
# var warn = document.getElementById("3dmolwarning_1750225816233232");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1750225816233232 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1750225816233232"),{backgroundColor:"white"});
# viewer_1750225816233232.zoomTo();
# 	viewer_1750225816233232.addModel("29\nXYZ from PySCF\nN           1.54139       -1.01165        0.59892\nH           1.73590       -1.28795        1.54671\nC           0.26971       -0.36320        0.31286\nH           0.03140       -0.59196       -0.72553\nC          -0.79876       -0.90640        1.24489\nH          -0.53265       -0.64130        2.26997\nH          -0.81093       -1.99435        1.15895\nC          -2.18532       -0.34732        0.95924\nH          -2.90257       -0.76801        1.66446\nH          -2.17919        0.73546        1.07296\nS          -2.71020       -0.77453       -0.72575\nC          -4.30224        0.07657       -0.70979\nH          -4.76350       -0.07639       -1.68210\nH          -4.16380        1.14306       -0.54599\nH          -4.95240       -0.33449        0.05972\nC           0.42867        1.15474        0.46591\nO           0.05694        1.75546        1.47127\nN           1.03216        1.73558       -0.59273\nH           1.43857        1.11077       -1.27828\nC           2.51783       -1.12201       -0.33614\nO           2.38786       -0.68277       -1.47827\nC           3.77093       -1.83532        0.10335\nH           4.61909       -1.17315       -0.05189\nH           3.91052       -2.70597       -0.53303\nH           3.74431       -2.15199        1.14288\nC           1.39296        3.13642       -0.57630\nH           2.39786        3.29377       -0.18332\nH           1.33891        3.53900       -1.58398\nH           0.68921        3.66041        0.06289","xyz");
# 	viewer_1750225816233232.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_1750225816233232.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_1750225816233232.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_1750225816233232.zoomTo();
# viewer_1750225816233232.render();
# });
# </script>
