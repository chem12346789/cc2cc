# %%
import py3Dmol

from cc2cc.utils import gen_mole

name_mol_list = [
    "SIE4x4-nh32+_1.0",
    "SIE4x4-nh32+_1.25",
    "SIE4x4-nh32+_1.5",
    "SIE4x4-nh32+_1.75",
]

for name_mol in name_mol_list:
    # Generate the molecule with the specified parameters
    # The parameters are:
    #       name, stratch_atom, stratch_orientation, stratch_distance and basis set
    mol = gen_mole(
        name_mol,
        0,
        1,
        0,
        "def2-TZVPP",
        True,
        "filtered_gmtkn-def2-TZVPP",
        solve_symmetry=True,
        verbose=0,
    )
    print(f"number of atomic orbitals: {mol.nao}")

    xyz = mol.tostring(format="xyz")

    xyzview = py3Dmol.view()
    xyzview.addModel(xyz, "xyz")
    xyzview.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
    xyzview.setStyle(
        {
            "stick": {},
            "sphere": {"scale": 0.3},
            "label": "atom",
        }
    )
    xyzview.setHoverable(
        {},
        True,
        """function(atom,viewer,event,container) {
            if(!atom.label) {
            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});
            }}""",
        """function(atom,viewer) {
            if(atom.label) {
            viewer.removeLabel(atom.label);
            delete atom.label;
            }
        }""",
        viewer=(0, 0),
    )
    xyzview.zoomTo()
    xyzview.show()
# Out:
# DEBUG True
# DEBUG [array(['H', np.float64(0.84297303), np.float64(0.48669071),
#        np.float64(-1.35892883)], dtype=object), array(['H', np.float64(0.0), np.float64(-0.97338141),
#        np.float64(-1.35892883)], dtype=object), array(['H', np.float64(-0.84297303), np.float64(0.48669071),
#        np.float64(-1.35892883)], dtype=object), array(['H', np.float64(0.84297303), np.float64(-0.48669071),
#        np.float64(1.35892883)], dtype=object), array(['H', np.float64(0.0), np.float64(0.97338141),
#        np.float64(1.35892883)], dtype=object), array(['H', np.float64(-0.84297303), np.float64(-0.48669071),
#        np.float64(1.35892883)], dtype=object), array(['N', np.float64(0.0), np.float64(0.0), np.float64(-1.08325539)],
#       dtype=object), array(['N', np.float64(0.0), np.float64(0.0), np.float64(1.08325539)],
#       dtype=object)]
# DEBUG [96.96505236 96.96505233 19.94138282] [[ 1.00000000e+00  1.23646075e-08 -7.13651930e-27]
#  [ 0.00000000e+00  1.00000000e+00 -1.23777136e-09]
#  [ 0.00000000e+00  1.23777136e-09  1.00000000e+00]]
# DEBUG [19.94138282 96.96505233 96.96505236] [[-1.00000000e+00  1.23777135e-09 -1.53045570e-17]
#  [-1.23777135e-09 -1.00000000e+00  1.23646075e-08]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# DEBUG [19.94138282 96.96505233 96.96505236] [[ 1.00000000e+00 -6.39777952e-18 -7.91060329e-26]
#  [ 0.00000000e+00  1.00000000e+00  1.23646075e-08]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# number of atomic orbitals: 146
# <div id="3dmolviewer_17555946941982906"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17555946941982906" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17555946941982906 = null;
# var warn = document.getElementById("3dmolwarning_17555946941982906");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17555946941982906 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17555946941982906"),{backgroundColor:"white"});
# viewer_17555946941982906.zoomTo();
# 	viewer_17555946941982906.addModel("8\nXYZ from PySCF\nH          -1.35892883       -0.48669071       -0.84297303\nH          -1.35892883       -0.48669071        0.84297303\nH          -1.35892883        0.97338141        0.00000000\nH           1.35892883       -0.97338141        0.00000000\nH           1.35892883        0.48669071       -0.84297303\nH           1.35892883        0.48669071        0.84297303\nN          -1.08325539        0.00000000        0.00000000\nN           1.08325539       -0.00000000        0.00000000","xyz");
# 	viewer_17555946941982906.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17555946941982906.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17555946941982906.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17555946941982906.zoomTo();
# viewer_17555946941982906.render();
# });
# </script>
# DEBUG True
# DEBUG [array(['H', np.float64(0.84297303), np.float64(0.48669071),
#        np.float64(-1.62974268)], dtype=object), array(['H', np.float64(0.0), np.float64(-0.97338141),
#        np.float64(-1.62974268)], dtype=object), array(['H', np.float64(-0.84297303), np.float64(0.48669071),
#        np.float64(-1.62974268)], dtype=object), array(['H', np.float64(0.84297303), np.float64(-0.48669071),
#        np.float64(1.62974268)], dtype=object), array(['H', np.float64(0.0), np.float64(0.97338141),
#        np.float64(1.62974268)], dtype=object), array(['H', np.float64(-0.84297303), np.float64(-0.48669071),
#        np.float64(1.62974268)], dtype=object), array(['N', np.float64(0.0), np.float64(0.0), np.float64(-1.35406924)],
#       dtype=object), array(['N', np.float64(0.0), np.float64(0.0), np.float64(1.35406924)],
#       dtype=object)]
# DEBUG [141.07146038 141.07146035  19.94138282] [[ 1.00000000e+00  1.23646027e-08 -3.46061426e-27]
#  [ 0.00000000e+00  1.00000000e+00 -9.43919521e-10]
#  [ 0.00000000e+00  9.43919521e-10  1.00000000e+00]]
# DEBUG [ 19.94138282 141.07146035 141.07146038] [[-1.00000000e+00 -9.43919506e-10  2.99367886e-18]
#  [-9.43919506e-10  1.00000000e+00  1.23646043e-08]
#  [ 1.46648700e-17 -1.55361447e-08  1.00000000e+00]]
# DEBUG [ 19.94138282 141.07146035 141.07146038] [[ 1.00000000e+00 -1.70047475e-17  1.04927241e-17]
#  [ 0.00000000e+00  1.00000000e+00 -6.06930513e-07]
#  [ 0.00000000e+00 -2.11262915e-07 -1.00000000e+00]]
# number of atomic orbitals: 146
# <div id="3dmolviewer_17555946943050165"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17555946943050165" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17555946943050165 = null;
# var warn = document.getElementById("3dmolwarning_17555946943050165");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17555946943050165 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17555946943050165"),{backgroundColor:"white"});
# viewer_17555946943050165.zoomTo();
# 	viewer_17555946943050165.addModel("8\nXYZ from PySCF\nH          -1.62974268       -0.97338141        0.00000002\nH          -1.62974268        0.48669070       -0.84297304\nH          -1.62974268        0.48669072        0.84297302\nH           1.62974268       -0.48669072       -0.84297302\nH           1.62974268       -0.48669070        0.84297304\nH           1.62974268        0.97338141       -0.00000002\nN          -1.35406924       -0.00000000        0.00000000\nN           1.35406924        0.00000000       -0.00000000","xyz");
# 	viewer_17555946943050165.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17555946943050165.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17555946943050165.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17555946943050165.zoomTo();
# viewer_17555946943050165.render();
# });
# </script>
# DEBUG True
# DEBUG [array(['H', np.float64(-1.90055702), np.float64(-0.84259382),
#        np.float64(-0.48734709)], dtype=object), array(['H', np.float64(-1.90055696), np.float64(-0.00075784),
#        np.float64(0.97338078)], dtype=object), array(['H', np.float64(-1.90055702), np.float64(0.84335167),
#        np.float64(-0.48603446)], dtype=object), array(['H', np.float64(1.90055702), np.float64(-0.84335167),
#        np.float64(0.48603446)], dtype=object), array(['H', np.float64(1.90055696), np.float64(0.00075784),
#        np.float64(-0.97338078)], dtype=object), array(['H', np.float64(1.90055702), np.float64(0.84259382),
#        np.float64(0.48734709)], dtype=object), array(['N', np.float64(-1.624883), np.float64(0.0), np.float64(7e-08)],
#       dtype=object), array(['N', np.float64(1.624883), np.float64(0.0), np.float64(-7e-08)],
#       dtype=object)]
# DEBUG [ 19.94138045 194.28096752 194.28096846] [[-1.00000000e+00  7.29755609e-10  3.44833036e-08]
#  [ 7.66638457e-10 -9.99058869e-01  4.33747952e-02]
#  [-3.44825033e-08 -4.33748254e-02 -9.99058871e-01]]
# DEBUG [ 19.94138045 194.28096752 194.28096846] [[-1.00000000e+00  1.58999729e-06 -2.64178048e-14]
#  [ 1.58999729e-06  1.00000000e+00 -1.66291015e-08]
#  [ 2.24213077e-17  1.41014754e-11  1.00000000e+00]]
# DEBUG [ 19.94138045 194.28096752 194.28096846] [[ 1.00000000e+00 -4.74045481e-18 -1.36301093e-19]
#  [ 0.00000000e+00  1.00000000e+00  1.69788202e-08]
#  [ 0.00000000e+00  1.60362169e-08 -1.00000000e+00]]
# number of atomic orbitals: 146
# <div id="3dmolviewer_17555946944188743"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17555946944188743" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17555946944188743 = null;
# var warn = document.getElementById("3dmolwarning_17555946944188743");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17555946944188743 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17555946944188743"),{backgroundColor:"white"});
# viewer_17555946944188743.zoomTo();
# 	viewer_17555946944188743.addModel("8\nXYZ from PySCF\nH          -1.90055704       -0.86293941        0.45034103\nH          -1.90055693        0.04146307       -0.97249764\nH          -1.90055704        0.82147632        0.52215718\nH           1.90055704       -0.82147632       -0.52215718\nH           1.90055693       -0.04146307        0.97249764\nH           1.90055704        0.86293941       -0.45034103\nN          -1.62488300        0.00000000       -0.00000013\nN           1.62488300       -0.00000000        0.00000013","xyz");
# 	viewer_17555946944188743.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17555946944188743.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17555946944188743.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17555946944188743.zoomTo();
# viewer_17555946944188743.render();
# });
# </script>
# DEBUG True
# DEBUG [array(['H', np.float64(0.84297303), np.float64(0.48669071),
#        np.float64(-2.17137038)], dtype=object), array(['H', np.float64(0.0), np.float64(-0.97338141),
#        np.float64(-2.17137038)], dtype=object), array(['H', np.float64(-0.84297303), np.float64(0.48669071),
#        np.float64(-2.17137038)], dtype=object), array(['H', np.float64(0.84297303), np.float64(-0.48669071),
#        np.float64(2.17137038)], dtype=object), array(['H', np.float64(0.0), np.float64(0.97338141),
#        np.float64(2.17137038)], dtype=object), array(['H', np.float64(-0.84297303), np.float64(-0.48669071),
#        np.float64(2.17137038)], dtype=object), array(['N', np.float64(0.0), np.float64(0.0), np.float64(-1.89569694)],
#       dtype=object), array(['N', np.float64(0.0), np.float64(0.0), np.float64(1.89569694)],
#       dtype=object)]
# DEBUG [256.59350198 256.59350194  19.94138282] [[ 1.00000000e+00  1.23646222e-08 -1.20795640e-27]
#  [ 0.00000000e+00  1.00000000e+00 -6.43711748e-10]
#  [ 0.00000000e+00  6.43711748e-10  1.00000000e+00]]
# DEBUG [ 19.94138282 256.59350194 256.59350198] [[-1.00000000e+00  6.43711741e-10 -7.95925250e-18]
#  [-6.43711741e-10 -1.00000000e+00  1.23646222e-08]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# DEBUG [ 19.94138282 256.59350194 256.59350198] [[1.00000000e+00 1.26257794e-18 0.00000000e+00]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# number of atomic orbitals: 146
# <div id="3dmolviewer_17555946945284605"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17555946945284605" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17555946945284605 = null;
# var warn = document.getElementById("3dmolwarning_17555946945284605");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17555946945284605 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17555946945284605"),{backgroundColor:"white"});
# viewer_17555946945284605.zoomTo();
# 	viewer_17555946945284605.addModel("8\nXYZ from PySCF\nH          -2.17137038       -0.48669071       -0.84297303\nH          -2.17137038       -0.48669071        0.84297303\nH          -2.17137038        0.97338141        0.00000000\nH           2.17137038       -0.97338141        0.00000000\nH           2.17137038        0.48669071       -0.84297303\nH           2.17137038        0.48669071        0.84297303\nN          -1.89569694        0.00000000        0.00000000\nN           1.89569694       -0.00000000        0.00000000","xyz");
# 	viewer_17555946945284605.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17555946945284605.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17555946945284605.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17555946945284605.zoomTo();
# viewer_17555946945284605.render();
# });
# </script>

# %%
import numpy as np
data1 = np.load(
    "/home/dhem/workspace/2025.1/data/UPU23-8d_cc-pVDZ_0_1_0.0000_default_cc.npz"
)
data2 = np.load(
    "/home/dhem/workspace/2025.1/data/test_no_grad/UPU23-8d_cc-pVDZ_0_1_0.0000_default_cc.npz"
)

# %%
print(
    data1["cc_dipole"] - data2["cc_dipole"],
    (data1["e_cc"] - data2["e_cc"]) * 627.5094733748099,
)
print(
    data1["dft_dipole"] - data2["dft_dipole"],
    (data1["e_dft"] - data2["e_dft"]) * 627.5094733748099,
)
