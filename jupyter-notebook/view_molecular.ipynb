# %%
import py3Dmol

from cc2cc.utils import gen_mole

name_mol_list = [
    "PArel-c2cl41",
    "PArel-c2cl42",
    "PArel-c2cl43",
    # "Amino20x4-MET_xag",
    # "Amino20x4-MET_xav",
    # "Amino20x4-MET_xbf",
    # "Amino20x4-MET_xbm",
    # "Amino20x4-MET_xbo",
]

for name_mol in name_mol_list:
    # Generate the molecule with the specified parameters
    # The parameters are:
    #       name, stratch_atom, stratch_orientation, stratch_distance and basis set
    mol = gen_mole(name_mol, 0, 1, 0, "cc-pVDZ", True, "gmtkn")
    print(f"number of atomic orbitals: {mol.nao}")

    xyz = mol.tostring(format="xyz")

    xyzview = py3Dmol.view()
    xyzview.addModel(xyz, "xyz")
    xyzview.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
    xyzview.setStyle(
        {
            "stick": {},
            "sphere": {"scale": 0.3},
            "label": "atom",
        }
    )
    xyzview.setHoverable(
        {},
        True,
        """function(atom,viewer,event,container) {
            if(!atom.label) {
            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});
            }}""",
        """function(atom,viewer) {
            if(atom.label) {
            viewer.removeLabel(atom.label);
            delete atom.label;
            }
        }""",
        viewer=(0, 0),
    )
    xyzview.zoomTo()
    xyzview.show()
# Out:
# number of atomic orbitals: 105
# <div id="3dmolviewer_17534153169814825"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17534153169814825" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17534153169814825 = null;
# var warn = document.getElementById("3dmolwarning_17534153169814825");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17534153169814825 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17534153169814825"),{backgroundColor:"white"});
# viewer_17534153169814825.zoomTo();
# 	viewer_17534153169814825.addModel("7\nXYZ from PySCF\nC           0.66671060        0.00000000        0.37020880\nC          -0.66671060        0.00000000        0.37020880\nCl          1.65413890        0.00000000        1.71516790\nCl          1.47342450        0.00000000       -1.20290260\nCl         -1.65413890        0.00000000        1.71516790\nCl         -1.47342450        0.00000000       -1.20290260\nH           0.00000000        0.00000000       -1.76494830","xyz");
# 	viewer_17534153169814825.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17534153169814825.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17534153169814825.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17534153169814825.zoomTo();
# viewer_17534153169814825.render();
# });
# </script>
# number of atomic orbitals: 105
# <div id="3dmolviewer_17534153170124588"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17534153170124588" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17534153170124588 = null;
# var warn = document.getElementById("3dmolwarning_17534153170124588");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17534153170124588 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17534153170124588"),{backgroundColor:"white"});
# viewer_17534153170124588.zoomTo();
# 	viewer_17534153170124588.addModel("7\nXYZ from PySCF\nC          -0.25177330        0.27568680        0.00000000\nC           1.07677150        0.18142100        0.00000000\nCl         -1.26542270        1.59931250        0.00000000\nCl         -1.09844490       -1.36718750        0.00000000\nCl          2.01856760        1.57604760        0.00000000\nCl          1.85330520       -1.32827850        0.00000000\nH          -2.33300340       -0.93700190        0.00000000","xyz");
# 	viewer_17534153170124588.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17534153170124588.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17534153170124588.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17534153170124588.zoomTo();
# viewer_17534153170124588.render();
# });
# </script>
# number of atomic orbitals: 105
# <div id="3dmolviewer_17534153170410104"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17534153170410104" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17534153170410104 = null;
# var warn = document.getElementById("3dmolwarning_17534153170410104");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17534153170410104 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17534153170410104"),{backgroundColor:"white"});
# viewer_17534153170410104.zoomTo();
# 	viewer_17534153170410104.addModel("7\nXYZ from PySCF\nC           0.00000000       -0.70865400        0.09964850\nC           0.00000000        0.70865400        0.09964850\nCl         -1.44590670       -1.57042560        0.21086080\nCl          1.44590670       -1.57042560        0.21086080\nCl         -1.44590670        1.57042560        0.21086080\nCl          1.44590670        1.57042560        0.21086080\nH           0.00000000        0.00000000       -1.04274020","xyz");
# 	viewer_17534153170410104.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17534153170410104.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17534153170410104.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17534153170410104.zoomTo();
# viewer_17534153170410104.render();
# });
# </script>

# %%
import numpy as np
data1 = np.load(
    "/home/dhem/workspace/2025.1/data/UPU23-8d_cc-pVDZ_0_1_0.0000_default_cc.npz"
)
data2 = np.load(
    "/home/dhem/workspace/2025.1/data/test_no_grad/UPU23-8d_cc-pVDZ_0_1_0.0000_default_cc.npz"
)

# %%
print(
    data1["cc_dipole"] - data2["cc_dipole"],
    (data1["e_cc"] - data2["e_cc"]) * 627.5094733748099,
)
print(
    data1["dft_dipole"] - data2["dft_dipole"],
    (data1["e_dft"] - data2["e_dft"]) * 627.5094733748099,
)
# Out:
# [ 0.08767197  0.07448193 -0.40654201] 55.65079834576539
# [ 1.18146470e-05 -2.07149526e-05  7.20604481e-05] 5.079377217985719e-08
