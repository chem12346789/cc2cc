# %%
import py3Dmol

from cc2cc.utils import gen_mole

name_mol_list = [
    "ADIM6-AD2",
]

for name_mol in name_mol_list:
    # Generate the molecule with the specified parameters
    # The parameters are:
    #       name, stratch_atom, stratch_orientation, stratch_distance and basis set
    mol = gen_mole(
        name_mol,
        0,
        1,
        0,
        "def2-TZVPP",
        True,
        "filtered_gmtkn-def2-TZVPP",
        if_rotate=True,
        if_rotate_random=False,
        solve_symmetry=True,
        verbose=0,
    )
    print(f"number of atomic orbitals: {mol.nao}")

    xyz = mol.tostring(format="xyz")
    print(xyz)

    xyzview = py3Dmol.view()
    xyzview.addModel(xyz, "xyz")
    xyzview.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
    xyzview.setStyle(
        {
            "stick": {},
            "sphere": {"scale": 0.3},
            "label": "atom",
        }
    )
    xyzview.setHoverable(
        {},
        True,
        """function(atom,viewer,event,container) {
            if(!atom.label) {
            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});
            }}""",
        """function(atom,viewer) {
            if(atom.label) {
            viewer.removeLabel(atom.label);
            delete atom.label;
            }
        }""",
        viewer=(0, 0),
    )
    xyzview.zoomTo()
    xyzview.show()
# Out:
# DEBUG False
# DEBUG [array(['H', np.float64(1.48964553), np.float64(-0.40143414),
#        np.float64(-1.91148268)], dtype=object), array(['H', np.float64(0.81277329), np.float64(0.96966035),
#        np.float64(-2.794292)], dtype=object), array(['H', np.float64(0.81277329), np.float64(0.96966035),
#        np.float64(-1.02867337)], dtype=object), array(['H', np.float64(-1.48964553), np.float64(0.40143414),
#        np.float64(-1.91148268)], dtype=object), array(['H', np.float64(-0.81277329), np.float64(-0.96966035),
#        np.float64(-2.794292)], dtype=object), array(['H', np.float64(-0.81277329), np.float64(-0.96966035),
#        np.float64(-1.02867337)], dtype=object), array(['H', np.float64(1.48964553), np.float64(0.40143414),
#        np.float64(1.91148268)], dtype=object), array(['H', np.float64(0.81277329), np.float64(-0.96966035),
#        np.float64(2.794292)], dtype=object), array(['H', np.float64(0.81277329), np.float64(-0.96966035),
#        np.float64(1.02867337)], dtype=object), array(['H', np.float64(-1.48964553), np.float64(-0.40143414),
#        np.float64(1.91148268)], dtype=object), array(['H', np.float64(-0.81277329), np.float64(0.96966035),
#        np.float64(2.794292)], dtype=object), array(['H', np.float64(-0.81277329), np.float64(0.96966035),
#        np.float64(1.02867337)], dtype=object), array(['C', np.float64(0.68416024), np.float64(0.33775112),
#        np.float64(-1.91148268)], dtype=object), array(['C', np.float64(-0.68416024), np.float64(-0.33775112),
#        np.float64(-1.91148268)], dtype=object), array(['C', np.float64(0.68416024), np.float64(-0.33775112),
#        np.float64(1.91148268)], dtype=object), array(['C', np.float64(-0.68416024), np.float64(0.33775112),
#        np.float64(1.91148268)], dtype=object)]
# DEBUG [239.7034131  262.75033693  50.46782421] [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# DEBUG [239.7034131   50.46782421 262.75033693] [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# DEBUG [ 50.46782421 239.7034131  262.75033693] [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# number of atomic orbitals: 292
# 16
# XYZ from PySCF
# H          -1.91148268       -1.48964553       -0.40143414
# H          -2.79429200       -0.81277329        0.96966035
# H          -1.02867337       -0.81277329        0.96966035
# H          -2.79429200        0.81277329       -0.96966035
# H          -1.02867337        0.81277329       -0.96966035
# H          -1.91148268        1.48964553        0.40143414
# H           2.79429200       -0.81277329       -0.96966035
# H           1.02867337       -0.81277329       -0.96966035
# H           1.91148268       -1.48964553        0.40143414
# H           1.91148268        1.48964553       -0.40143414
# H           2.79429200        0.81277329        0.96966035
# H           1.02867337        0.81277329        0.96966035
# C          -1.91148268       -0.68416024        0.33775112
# C          -1.91148268        0.68416024       -0.33775112
# C           1.91148268       -0.68416024       -0.33775112
# C           1.91148268        0.68416024        0.33775112
# <div id="3dmolviewer_1756111976042698"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_1756111976042698" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_1756111976042698 = null;
# var warn = document.getElementById("3dmolwarning_1756111976042698");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1756111976042698 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1756111976042698"),{backgroundColor:"white"});
# viewer_1756111976042698.zoomTo();
# 	viewer_1756111976042698.addModel("16\nXYZ from PySCF\nH          -1.91148268       -1.48964553       -0.40143414\nH          -2.79429200       -0.81277329        0.96966035\nH          -1.02867337       -0.81277329        0.96966035\nH          -2.79429200        0.81277329       -0.96966035\nH          -1.02867337        0.81277329       -0.96966035\nH          -1.91148268        1.48964553        0.40143414\nH           2.79429200       -0.81277329       -0.96966035\nH           1.02867337       -0.81277329       -0.96966035\nH           1.91148268       -1.48964553        0.40143414\nH           1.91148268        1.48964553       -0.40143414\nH           2.79429200        0.81277329        0.96966035\nH           1.02867337        0.81277329        0.96966035\nC          -1.91148268       -0.68416024        0.33775112\nC          -1.91148268        0.68416024       -0.33775112\nC           1.91148268       -0.68416024       -0.33775112\nC           1.91148268        0.68416024        0.33775112","xyz");
# 	viewer_1756111976042698.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_1756111976042698.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_1756111976042698.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_1756111976042698.zoomTo();
# viewer_1756111976042698.render();
# });
# </script>

# %%
# import numpy as np
# data1 = np.load(
#     "/home/dhem/workspace/2025.1/data/UPU23-8d_cc-pVDZ_0_1_0.0000_default_cc.npz"
# )
# data2 = np.load(
#     "/home/dhem/workspace/2025.1/data/test_no_grad/UPU23-8d_cc-pVDZ_0_1_0.0000_default_cc.npz"
# )

# %%
# print(
#     data1["cc_dipole"] - data2["cc_dipole"],
#     (data1["e_cc"] - data2["e_cc"]) * 627.5094733748099,
# )
# print(
#     data1["dft_dipole"] - data2["dft_dipole"],
#     (data1["e_dft"] - data2["e_dft"]) * 627.5094733748099,
# )

# %%
import numpy as np
np.sqrt(0.004**2*3)
# Out:
# np.float64(0.0069282032302755096)
