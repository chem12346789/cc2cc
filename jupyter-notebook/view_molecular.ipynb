# %%
import py3Dmol

from cc2cc.utils import gen_mole

name_mol_list = [
    "AL2X6-alh3",
    "MB16_43-AlH3",
    "W4_11-alh3",
]

for name_mol in name_mol_list:
    # Generate the molecule with the specified parameters
    # The parameters are:
    #       name, stratch_atom, stratch_orientation, stratch_distance and basis set
    mol = gen_mole(
        name_mol,
        0,
        1,
        0,
        "def2-TZVPP",
        True,
        "filtered_gmtkn-def2-TZVPP",
        solve_symmetry=True,
        verbose=0,
    )
    print(f"number of atomic orbitals: {mol.nao}")

    xyz = mol.tostring(format="xyz")

    xyzview = py3Dmol.view()
    xyzview.addModel(xyz, "xyz")
    xyzview.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
    xyzview.setStyle(
        {
            "stick": {},
            "sphere": {"scale": 0.3},
            "label": "atom",
        }
    )
    xyzview.setHoverable(
        {},
        True,
        """function(atom,viewer,event,container) {
            if(!atom.label) {
            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});
            }}""",
        """function(atom,viewer) {
            if(atom.label) {
            viewer.removeLabel(atom.label);
            delete atom.label;
            }
        }""",
        viewer=(0, 0),
    )
    xyzview.zoomTo()
    xyzview.show()
# Out:
# DEBUG True
# DEBUG [array(['H', np.float64(0.0), np.float64(0.0), np.float64(1.578518)],
#       dtype=object), array(['H', np.float64(-1.367037), np.float64(0.0), np.float64(-0.789259)],
#       dtype=object), array(['H', np.float64(1.367037), np.float64(0.0), np.float64(-0.789259)],
#       dtype=object), array(['Al', np.float64(0.0), np.float64(0.0), np.float64(0.0)],
#       dtype=object)]
# DEBUG [ 5.34651205  9.66230003 15.00881208] [[-0.96592588 -0.25881885  0.        ]
#  [ 0.          0.          1.        ]
#  [ 0.25881885 -0.96592588  0.        ]]
# DEBUG [ 5.34651205  9.66230003 15.00881208] [[-0.96592588  0.25881885  0.        ]
#  [-0.25881885 -0.96592588  0.        ]
#  [ 0.          0.          1.        ]]
# DEBUG [ 5.34651205  9.66230003 15.00881208] [[1.00000000e+00 3.08696264e-16 0.00000000e+00]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# number of atomic orbitals: 84
# <div id="3dmolviewer_17555052702727745"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17555052702727745" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17555052702727745 = null;
# var warn = document.getElementById("3dmolwarning_17555052702727745");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17555052702727745 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17555052702727745"),{backgroundColor:"white"});
# viewer_17555052702727745.zoomTo();
# 	viewer_17555052702727745.addModel("4\nXYZ from PySCF\nH          -0.40855022       -1.52473138        0.00000000\nH          -1.11618130        1.11618064        0.00000000\nH           1.52473152        0.40855074        0.00000000\nAl          0.00000000        0.00000000        0.00000000","xyz");
# 	viewer_17555052702727745.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17555052702727745.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17555052702727745.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17555052702727745.zoomTo();
# viewer_17555052702727745.render();
# });
# </script>
# DEBUG True
# DEBUG [array(['H', np.float64(-0.7926513966411446), np.float64(1.3729124),
#        np.float64(0.0)], dtype=object), array(['H', np.float64(-0.7926513966411446), np.float64(-1.3729124),
#        np.float64(0.0)], dtype=object), array(['H', np.float64(1.5853027033588554), np.float64(0.0),
#        np.float64(0.0)], dtype=object), array(['Al', np.float64(3.35885544289457e-09), np.float64(0.0),
#        np.float64(0.0)], dtype=object)]
# DEBUG [ 5.39257073  9.74553459 15.13810532] [[-0.96592583  0.25881904  0.        ]
#  [-0.25881904 -0.96592583  0.        ]
#  [ 0.          0.          1.        ]]
# DEBUG [ 5.39257073  9.74553459 15.13810532] [[-0.96592583  0.25881904  0.        ]
#  [-0.25881904 -0.96592583  0.        ]
#  [ 0.          0.          1.        ]]
# DEBUG [ 5.39257073  9.74553459 15.13810532] [[ 1.00000000e+00 -8.25936006e-17  0.00000000e+00]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# number of atomic orbitals: 84
# <div id="3dmolviewer_1755505270332984"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_1755505270332984" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_1755505270332984 = null;
# var warn = document.getElementById("3dmolwarning_1755505270332984");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1755505270332984 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1755505270332984"),{backgroundColor:"white"});
# viewer_1755505270332984.zoomTo();
# 	viewer_1755505270332984.addModel("4\nXYZ from PySCF\nH          -0.41030659       -1.53128482        0.00000000\nH          -1.12097832        1.12097828        0.00000000\nH           1.53128483        0.41030652        0.00000000\nAl          0.00000000        0.00000000        0.00000000","xyz");
# 	viewer_1755505270332984.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_1755505270332984.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_1755505270332984.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_1755505270332984.zoomTo();
# viewer_1755505270332984.render();
# });
# </script>
# DEBUG True
# DEBUG [array(['H', np.float64(0.0), np.float64(1.5805), np.float64(0.0)],
#       dtype=object), array(['H', np.float64(1.368753), np.float64(-0.79025), np.float64(0.0)],
#       dtype=object), array(['H', np.float64(-1.368753), np.float64(-0.79025), np.float64(0.0)],
#       dtype=object), array(['Al', np.float64(0.0), np.float64(0.0), np.float64(0.0)],
#       dtype=object)]
# DEBUG [ 5.35994648  9.68657328 15.04651976] [[-0.9659258   0.25881914  0.        ]
#  [-0.25881914 -0.9659258   0.        ]
#  [ 0.          0.          1.        ]]
# DEBUG [ 5.35994648  9.68657328 15.04651976] [[-0.9659258   0.25881914  0.        ]
#  [-0.25881914 -0.9659258   0.        ]
#  [ 0.          0.          1.        ]]
# DEBUG [ 5.35994648  9.68657328 15.04651976] [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# number of atomic orbitals: 84
# <div id="3dmolviewer_17555052703917415"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17555052703917415" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17555052703917415 = null;
# var warn = document.getElementById("3dmolwarning_17555052703917415");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17555052703917415 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17555052703917415"),{backgroundColor:"white"});
# viewer_17555052703917415.zoomTo();
# 	viewer_17555052703917415.addModel("4\nXYZ from PySCF\nH          -0.40906365       -1.52664573        0.00000000\nH          -1.11758202        1.11758234        0.00000000\nH           1.52664566        0.40906339        0.00000000\nAl          0.00000000        0.00000000        0.00000000","xyz");
# 	viewer_17555052703917415.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17555052703917415.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17555052703917415.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17555052703917415.zoomTo();
# viewer_17555052703917415.render();
# });
# </script>

# %%
import numpy as np
data1 = np.load(
    "/home/dhem/workspace/2025.1/data/UPU23-8d_cc-pVDZ_0_1_0.0000_default_cc.npz"
)
data2 = np.load(
    "/home/dhem/workspace/2025.1/data/test_no_grad/UPU23-8d_cc-pVDZ_0_1_0.0000_default_cc.npz"
)

# %%
print(
    data1["cc_dipole"] - data2["cc_dipole"],
    (data1["e_cc"] - data2["e_cc"]) * 627.5094733748099,
)
print(
    data1["dft_dipole"] - data2["dft_dipole"],
    (data1["e_dft"] - data2["e_dft"]) * 627.5094733748099,
)
