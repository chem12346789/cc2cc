# %%
import py3Dmol

from cc2cc.utils import gen_mole

name_mol_list = [
    "ISOL24-i4p",
    # "Amino20x4-MET_xag",
    # "Amino20x4-MET_xav",
    # "Amino20x4-MET_xbf",
    # "Amino20x4-MET_xbm",
    # "Amino20x4-MET_xbo",
]

for name_mol in name_mol_list:
    # Generate the molecule with the specified parameters
    # The parameters are:
    #       name, stratch_atom, stratch_orientation, stratch_distance and basis set
    mol = gen_mole(name_mol, 0, 1, 0, "cc-pVDZ", True, "gmtkn")
    print(f"number of atomic orbitals: {mol.nao}")

    xyz = mol.tostring(format="xyz")

    xyzview = py3Dmol.view()
    xyzview.addModel(xyz, "xyz")
    xyzview.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
    xyzview.setStyle(
        {
            "stick": {},
            "sphere": {"scale": 0.3},
            "label": "atom",
        }
    )
    xyzview.setHoverable(
        {},
        True,
        """function(atom,viewer,event,container) {
            if(!atom.label) {
            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});
            }}""",
        """function(atom,viewer) {
            if(atom.label) {
            viewer.removeLabel(atom.label);
            delete atom.label;
            }
        }""",
        viewer=(0, 0),
    )
    xyzview.zoomTo()
    xyzview.show()
# Out:
# number of atomic orbitals: 684
# <div id="3dmolviewer_17532601366388066"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17532601366388066" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17532601366388066 = null;
# var warn = document.getElementById("3dmolwarning_17532601366388066");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17532601366388066 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17532601366388066"),{backgroundColor:"white"});
# viewer_17532601366388066.zoomTo();
# 	viewer_17532601366388066.addModel("81\nXYZ from PySCF\nC          11.77012        1.41797       -0.37770\nC          13.25608        1.13451       -0.50252\nC          10.84194        0.28190       -0.19942\nC           9.49291        0.33849        0.47820\nC           8.47298       -0.58120       -0.23188\nC           7.10558       -0.56356        0.41592\nC           6.05179       -0.03756       -0.23059\nC           4.62860        0.05572        0.24448\nC           3.70912       -0.96074       -0.48804\nC           2.25818       -0.85932       -0.07106\nC           1.32592       -0.42485       -0.93575\nC          -0.15053       -0.26521       -0.70461\nC          -0.98249       -1.29431       -1.52075\nC          -2.45984       -1.08253       -1.34477\nC          -3.33812       -1.85493       -0.68253\nC          -4.78804       -1.43698       -0.56617\nC          -5.21572       -1.11107        0.89222\nC          -6.65799       -0.69641        0.96822\nC          -7.16021        0.52939        1.19523\nC          -8.65602        0.75851        1.17365\nC          -9.12231        1.63335       -0.02343\nC         -10.60929        1.85502       -0.01038\nC         -11.53589        1.27479       -0.79094\nC         -13.00322        1.59521       -0.62800\nC          11.43782        2.81637        0.10574\nC           7.04796       -1.15798        1.80339\nC           1.98019       -1.25924        1.35909\nC         -11.23852        0.27228       -1.87946\nH          11.91434        3.55547       -0.55262\nH          13.42468        0.11483       -0.86748\nH          10.35968        2.99903        0.10374\nH          11.82449        2.96815        1.12322\nH          13.71720        1.84060       -1.20682\nH          13.75108        1.25101        0.47169\nH          11.29974       -0.71603       -0.17769\nH           7.62087       -0.54785        2.51785\nH           6.02708       -1.25496        2.18507\nH           7.50987       -2.15711        1.80333\nH           0.91175       -1.32848        1.58485\nH           2.44068       -2.23611        1.57149\nH           2.42888       -0.54102        2.06160\nH          -5.06366       -2.00724        1.51132\nH          -4.97528       -0.55249       -1.18910\nH          -2.84521       -0.15890       -1.78646\nH          -0.71688       -1.18333       -2.58388\nH          -0.41142       -0.36495        0.35521\nH           1.65973       -0.18475       -1.94945\nH           3.80031       -0.80357       -1.57148\nH           6.22574        0.34007       -1.24187\nH         -13.41996        2.00155       -1.56320\nH         -13.17246        2.32501        0.17323\nH         -13.57849        0.68445       -0.39817\nH         -11.79078       -0.66189       -1.69319\nH         -10.17537        0.02731       -1.96356\nH         -11.58507        0.64996       -2.85420\nH           9.61845        0.02508        1.52514\nH           4.55772       -0.10264        1.32618\nO          10.96983        0.93050       -1.48978\nC          -2.99224       -3.15542        0.00247\nH          -3.12630       -3.06892        1.09083\nH          -3.67227       -3.95303       -0.33410\nH          -1.96399       -3.47932       -0.18398\nC          -6.32968        1.76224        1.46013\nH          -6.45616        2.49643        0.65086\nH          -6.66706        2.25463        2.38517\nH          -5.26070        1.54892        1.55373\nH          -7.37569       -1.49948        0.77703\nH          -9.18353       -0.20315        1.12529\nH         -10.96570        2.54921        0.75567\nH          -8.61316        2.60634        0.03103\nH           8.39802       -0.26615       -1.28013\nH           4.23925        1.06571        0.04561\nH          -0.46233        0.74644       -1.00925\nH           8.86937       -1.61036       -0.22421\nH           4.08816       -1.97244       -0.27271\nH           9.10416        1.36268        0.48150\nH          -0.67442       -2.30308       -1.22344\nH          -5.437 ...
# 	viewer_17532601366388066.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17532601366388066.setStyle({"stick": {}, "sphere": {"scale": 0.3}, "label": "atom"});
# 	viewer_17532601366388066.setHoverable({},true,"function(atom,viewer,event,container) {\n            if(!atom.label) {\n            atom.label = viewer.addLabel(atom.atom,{position: atom, backgroundColor: 'mintcream', fontColor:'black', fontSize: 18, fontWeight: 'bold', alignment: 'center', showBackground: true, showBorder: true, borderColor: 'black', borderWidth: 1, padding: 2, zIndex: 1000});\n            }}","function(atom,viewer) {\n            if(atom.label) {\n            viewer.removeLabel(atom.label);\n            delete atom.label;\n            }\n        }");
# 	viewer_17532601366388066.zoomTo();
# viewer_17532601366388066.render();
# });
# </script>

# %%
mol.nelec

# %%
import json
import numpy as np
with open(
    f"/home/dhem/workspace/2025.1/tmp_mol/W4_11-hcl_cc-pVDZ_0_1_0.0000_default/mol.property.json",
    "r",
) as f:
    data_json = json.load(f)
    print(data_json)
# Out:
# {'Calculation_Status': {'PropertyName': 'Calculation_Status', 'GeometryIndex': 1, 'VERSION': '6.0.1', 'PROGNAME': 'ProgMDCI', 'STATUS': 'NORMAL TERMINATION'}, 'Geometry_1': {'Geometry': {'PropertyName': 'Geometry', 'GeometryIndex': 1, 'NATOMS': 2, 'NCORELESSECP': 0, 'NGHOSTATOMS': 0, 'Coordinates': {'Type': 'Cartesians', 'Units': 'Bohr', 'Cartesians': [['Cl', 0.0, 0.0, 0.1339192213], ['H ', 0.0, 0.0, -2.276622982]]}}, 'SCF_Energy': {'PropertyName': 'SCF_Energy', 'GeometryIndex': 1, 'SCF_ENERGY': -460.0894480991549}, 'Mulliken_Population_Analysis': {'PropertyName': 'Mulliken_Population_Analysis', 'GeometryIndex': 1, 'NATOMS': 2, 'ATNO': [[17], [1]], 'ATOMICCHARGES': [[-0.1720652144186], [0.1720652144186]]}, 'Loewdin_Population_Analysis': {'PropertyName': 'Loewdin_Population_Analysis', 'GeometryIndex': 1, 'NATOMS': 2, 'ATNO': [[17], [1]], 'ATOMICCHARGES': [[-0.02161034761514], [0.02161034761513]]}, 'Mayer_Population_Analysis': [{'PropertyName': 'Mayer_Population_Analysis', 'GeometryIndex': 1, 'NATOMS': 2, 'BONDTHRESH': 0.1, 'NBONDORDERSPRINT': 1, 'BONDORDERS': [[0.9924662469406]], 'COMPONENTS': [[0, 17, 1, 1]], 'ATNO': [[17], [1]], 'NA': [[17.17206521442], [0.8279347855814]], 'ZA': [[17.0], [1.0]], 'QA': [[-0.1720652144186], [0.1720652144186]], 'VA': [[0.9924662469406], [0.9924662469406]], 'BVA': [[0.9924662469406], [0.9924662469406]], 'FA': [[0.0], [0.0]]}, {'PropertyName': 'Mayer_Population_Analysis', 'GeometryIndex': 1, 'NATOMS': 2, 'BONDTHRESH': 0.1, 'NBONDORDERSPRINT': 1, 'BONDORDERS': [[0.9428234840728]], 'COMPONENTS': [[0, 17, 1, 1]], 'ATNO': [[17], [1]], 'NA': [[17.15203747147], [0.8479625285262]], 'ZA': [[17.0], [1.0]], 'QA': [[-0.1520374714738], [0.1520374714738]], 'VA': [[1.385830898552], [1.014512516256]], 'BVA': [[0.9428234840728], [0.9428234840728]], 'FA': [[0.4430074144789], [0.07168903218321]]}], 'MDCI_Energies': {'PropertyName': 'MDCI_Energies', 'GeometryIndex': 1, 'NUMOFEL': 18, 'NUMOFCORREL': 18, 'NUMOFALPHACORREL': 9, 'NUMOFBETACORREL': 9, 'REFENERGY': -460.0894480993342, 'CORRENERGY': -0.16847362219409506, 'AACORREN': -0.01838874369616973, 'BBCORREN': -0.01838874369616973, 'ABCORREN': -0.1316434271073994, 'CORRDS': 0.0, 'CORRDT': 0.0, 'CORRSS': 0.0, 'CORRST': 0.0, 'TRIPLESENERGY': 0.0, 'TOTALENERGY': -460.2579217215283}, 'Calculation_Info': {'PropertyName': 'Calculation_Info', 'GeometryIndex': 1, 'MULT': 1, 'CHARGE': 0, 'NUMOFATOMS': 2, 'NUMOFELECTRONS': 18, 'NUMOFFCELECTRONS': 0, 'NUMOFCORRELECTRONS': 0, 'NUMOFBASISFUNCTS': 23, 'NUMOFAUXCBASISFUNCTS': 90, 'NUMOFAUXJBASISFUNCTS': 0, 'NUMOFAUXJKBASISFUNCTS': 0, 'NUMOFCABSBASISFUNCTS': 0, 'TOTALENERGY': -460.2579217215283}, 'Dipole_Moment': [{'PropertyName': 'SCF_Dipole_Moment', 'GeometryIndex': 1, 'METHOD': 'SCF', 'LEVEL': 'Relaxed density', 'MULT': 1, 'STATE': -1, 'IRREP': 0, 'NATOMS': 2, 'DODIPOLEATOM': False, 'DIPOLEELECCONTRIB': [[0.0], [0.0], [0.6539578660686]], 'DIPOLENUCCONTRIB': [[0.0], [0.0], [-1.210989866922]], 'DIPOLETOTAL': [[0.0], [0.0], [-0.5570320008534]], 'DIPOLEMAGNITUDE': 0.5570320008534494}, {'PropertyName': 'MDCI_Dipole_Moment', 'GeometryIndex': 1, 'METHOD': 'MDCI(SD)', 'LEVEL': 'Unrelaxed density', 'MULT': 1, 'STATE': -1, 'IRREP': 0, 'NATOMS': 2, 'DODIPOLEATOM': False, 'DIPOLEELECCONTRIB': [[5.356497034318e-09], [1.795378278044e-09], [0.6891573116482]], 'DIPOLENUCCONTRIB': [[0.0], [0.0], [-1.210989866922]], 'DIPOLETOTAL': [[5.356497034318e-09], [1.795378278044e-09], [-0.5218325552739]], 'DIPOLEMAGNITUDE': 0.5218325552738607}]}}

# %%
data1 = np.load(
    "/home/dhem/workspace/2025.1/data/W4_11-hcl_cc-pVDZ_0_1_0.0000_default_cc.npz"
)
data2 = np.load(
    "/home/dhem/workspace/2025.1/data/test_no_grad/W4_11-hcl_cc-pVDZ_0_1_0.0000_default_cc.npz"
)

# %%
data1["cc_dipole"] - data2["cc_dipole"], (data1["e_cc"] - data2["e_cc"]) * 627.5094733748099
# Out:
# (array([-5.36365859e-09, -1.80017715e-09, -6.29071608e-04]),
#  np.float64(0.18379400009852695))
